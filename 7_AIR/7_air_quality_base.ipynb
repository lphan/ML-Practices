# %%
# setup absolute path to location of package Starts and config-file 
from inspect import getsourcefile
import os.path as path, sys
current_dir = path.dirname(path.abspath(getsourcefile(lambda:0)))
sys.path.insert(0, current_dir[:current_dir.rfind(path.sep)])

# import package Starts
from Starts.startmod import *
# Out:
# local_kwargs {'data_path_1': './data/AirQualityUCI.xlsx', 'data_path_2': './data/AirQualityUCI.csv', 'data_path_3': '', 'drop_obj_col': False, 'nan_drop_col': False, 'nan_drop_row': False, 'nan_zero': False, 'nan_mean': True, 'nan_mean_neighbors': False}

# %%
StartML.summary(train_data)
# Out:
# Data Columns: Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')
#
# Missing values in Data:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64
#
# data.head(10):
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# ...

# %%
train_data.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# ...

# %%
train_data = StartMod.feature_engineering_merge_cols(train_data, ['Date', 'Time'], 'Date_Time', datetime=True)
train_data.head()
# Out:
#    CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     2.6      1360.00       150  11.881723        1045.50    166.0
# 1     2.0      1292.25       112   9.397165         954.75    103.0
# 2     2.2      1402.00        88   8.997817         939.25    131.0
# 3     2.2      1375.50        80   9.228796         948.25    172.0
# 4     1.6      1272.25        51   6.518224         835.50    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)      T         RH  \
# 0       1056.25    113.0       1692.00      1267.50  13.60  48.875001
# 1       1173.75     92.0       1558.75       972.25  13.30  47.700000
# 2       1140.00    114.0       1554.50      1074.00  11.90  53.975000
# 3       1092.00    122.0       1583.75      1203.25  11.00  60.000000
# 4       1205.00    116.0       1490.00      1110.00  11.15  59.575001
#
#          AH           Date_Time
# 0  0.757754 2004-03-10 18:00:00
# 1  0.725487 2004-03-10 19:00:00
# 2  0.750239 2004-03-10 20:00:00
# ...

# %%
StartML.idx_columns(train_data)
# Out:
# [('CO(GT)', 0, dtype('float64')),
#  ('PT08.S1(CO)', 1, dtype('float64')),
#  ('NMHC(GT)', 2, dtype('int64')),
#  ('C6H6(GT)', 3, dtype('float64')),
#  ('PT08.S2(NMHC)', 4, dtype('float64')),
#  ('NOx(GT)', 5, dtype('float64')),
#  ('PT08.S3(NOx)', 6, dtype('float64')),
#  ('NO2(GT)', 7, dtype('float64')),
#  ('PT08.S4(NO2)', 8, dtype('float64')),
#  ('PT08.S5(O3)', 9, dtype('float64')),
#  ('T', 10, dtype('float64')),
#  ('RH', 11, dtype('float64')),
#  ('AH', 12, dtype('float64')),
#  ('Date_Time', 13, dtype('<M8[ns]'))]

# %%
train_data = StartMod.convert_time_series(train_data, 'Date_Time')
train_data.head()
# Out:
#                      CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  \
# Date_Time
# 2004-03-10 18:00:00     2.6      1360.00       150  11.881723        1045.50
# 2004-03-10 19:00:00     2.0      1292.25       112   9.397165         954.75
# 2004-03-10 20:00:00     2.2      1402.00        88   8.997817         939.25
# 2004-03-10 21:00:00     2.2      1375.50        80   9.228796         948.25
# 2004-03-10 22:00:00     1.6      1272.25        51   6.518224         835.50
#
#                      NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# Date_Time
# 2004-03-10 18:00:00    166.0       1056.25    113.0       1692.00
# 2004-03-10 19:00:00    103.0       1173.75     92.0       1558.75
# 2004-03-10 20:00:00    131.0       1140.00    114.0       1554.50
# 2004-03-10 21:00:00    172.0       1092.00    122.0       1583.75
# 2004-03-10 22:00:00    131.0       1205.00    116.0       1490.00
#
#                      PT08.S5(O3)      T         RH        AH
# Date_Time
# ...

# %%
train_data.to_csv('./data/AirQualityUCI.csv', index=True)
