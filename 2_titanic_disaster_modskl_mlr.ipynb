# %% [markdown]
# ### Try Model: Multiple Linear Regression

# %%
from Starts.startmodskl import *

# %%
nonan_data.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare  Title  FamilySize
# 0         0       3    1  21.0   8.0500      5           0
# 1         0       1    1  47.0  25.5875      5           0
# 2         1       2    0   5.0  27.7500      4           3
# 3         0       3    1  49.0   0.0000      5           0
# 4         0       3    1  36.0   0.0000      5           0

# %%
regressor, y_true, y_pred = StartModSKL.regression_multi_linear(nonan_data, 'Survived')

regressor.summary()
# Out:
# x_value is optimal with pvalue  0.03689614549777558
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.396
# Model:                            OLS   Adj. R-squared:                  0.393
# Method:                 Least Squares   F-statistic:                     116.1
# Date:                Tue, 20 Feb 2018   Prob (F-statistic):           2.04e-94
# Time:                        17:52:58   Log-Likelihood:                -397.24
# No. Observations:                 891   AIC:                             806.5
# Df Residuals:                     885   BIC:                             835.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.4822      0.088     16.927      0.000       1.310       1.654
# x1            -0.1832      0.016    -11.196      0.000      -0.215      -0.151
# x2            -0.5218      0.028    -18.899      0.000      -0.576      -0.468
# x3            -0.0052      0.001     -4.647      0.000      -0.007      -0.003
# x4            -0.0314      0.015     -2.090      0.037      -0.061      -0.002
# x5            -0.0334      0.008     -4.008      0.000      -0.050      -0.017
# ==============================================================================
# Omnibus:                       35.225   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.481
# Skew:                           0.505   Prob(JB):                     4.41e-09
# Kurtosis:                       3.125   Cond. No.                         229.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Convert predicted value by rounding it (>0.5 will be considered as 1 else 0)
y_pred = np.array([np.round(item) for item in y_pred ])
len(y_true), len(y_pred)
# Out:
# (179, 179)

# %%
confusion_matrix(y_true, y_pred)
# Out:
# array([[85, 13],
#        [29, 52]])

# %% [markdown]
# ### Result:
# #### the correct predicted result 137,
# #### the wrong predicted result 42
