# %% [markdown]
# ### Question: what is the top five ranking of „Bundesländer“ in terms of marriages?

# %%
from Starts.startml import *
marriages_1950_2015 = train_data
marriages_groupby_age2015 = nonan_data
marriages_groupby_de_1994_2015 = test_data
# Out:
# local_kwargs {'data_path_1': '10_EY/marriages_1950_2015.csv', 'data_path_2': '10_EY/marriages_groupby_age2015.csv', 'data_path_3': '10_EY/marriages_groupby_de_1994_2015.csv', 'drop_obj_col': False, 'nan_drop_col': False, 'nan_drop_row': False, 'nan_zero': False, 'nan_mean': True, 'nan_mean_neighbors': False}

# %%
marriages_1950_2015.set_index('Jahr', inplace=True)

# %%
marriages_1950_2015.sort_values(by='Eheschließungen', ascending=False)
# Out:
#       Eheschließungen  Eheschließungen je 1000 Einwohner
# Jahr
# 1950           750452                               11.0
# 1951           718166                               10.4
# 1961           699339                                9.5
# 1962           696317                                9.4
# 1960           689028                                9.5
# 1959           665844                                9.2
# 1952           659779                                9.5
# 1963           655974                                8.8
# 1958           648471                                9.1
# 1964           642037                                8.5
# 1957           632659                                8.9
# 1956           630932                                8.9
# 1965           621130                                8.2
# 1953           620121                                8.9
# 1955           617228                                8.8
# ...

# %%
marriages_groupby_age2015.head(20)
# Out:
#    unter 15 Jahre 15 bis unter 20 Jahre 20 bis unter 25 Jahre  \
# 0               -                     -                     -
# 1               -                   353                   252
# 2               -                  1986                 13264
# 3               -                   917                 21255
# 4               -                   194                  5760
# 5               0                    51                  1445
# 6               -                    18                   425
# 7               -                    19                   205
# 8               -                     9                    86
# 9               -                     3                    38
# 10              -                     1                    14
# 11              -                     -                     1
# 12              -                     -                     2
# 13              -                     -                     3
#
# ...

# %%
marriages_groupby_de_1994_2015.columns[1:len(marriages_groupby_de_1994_2015.columns)]
# Out:
# Index(['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %%
len(marriages_groupby_de_1994_2015['Bundesländer']), len(marriages_groupby_de_1994_2015.drop('Bundesländer', axis=1).columns)
# Out:
# (16, 26)

# %%
# marriages_groupby_de_1994_2015.iloc[0][0], marriages_groupby_de_1994_2015.iloc[0][1:len(marriages_groupby_de_1994_2015.drop('Bundesländer', axis=1).columns)+1].mean()
# marriages_groupby_de_1994_2015.iloc[1][0], marriages_groupby_de_1994_2015.iloc[1][1:28].mean()
# marriages_groupby_de_1994_2015.iloc[0][0], np.mean(marriages_groupby_de_1994_2015.iloc[0][1:28])# 
data = [(marriages_groupby_de_1994_2015.iloc[i][0], marriages_groupby_de_1994_2015.iloc[i][1:len(marriages_groupby_de_1994_2015.drop('Bundesländer', axis=1).columns)+1].mean())  
                            for i in range(len(marriages_groupby_de_1994_2015['Bundesländer']))]
df = pd.DataFrame(data, columns=['States','Marriage_Mean'])

# %%
df.sort_values(by='Marriage_Mean', ascending=False)
# Out:
#                     States  Marriage_Mean
# 9      Nordrhein-Westfalen   92294.884615
# 1                   Bayern   63469.038462
# 0        Baden-Württemberg   53489.153846
# 8            Niedersachsen   42857.769231
# 6                   Hessen   30772.423077
# 10         Rheinland-Pfalz   21484.692308
# 14      Schleswig-Holstein   17252.500000
# 12                 Sachsen   16843.884615
# 2                   Berlin   14291.115385
# 3              Brandenburg   10741.423077
# 13          Sachsen-Anhalt   10201.346154
# 15               Thüringen    9370.884615
# 7   Mecklenburg-Vorpommern    8598.884615
# 5                  Hamburg    7542.769231
# 11                Saarland    5547.769231
# 4                   Bremen    3249.923077

# %%
df.sort_values(by='Marriage_Mean', ascending=False)[0:5]
# Out:
#                 States  Marriage_Mean
# 9  Nordrhein-Westfalen   92294.884615
# 1               Bayern   63469.038462
# 0    Baden-Württemberg   53489.153846
# 8        Niedersachsen   42857.769231
# 6               Hessen   30772.423077
