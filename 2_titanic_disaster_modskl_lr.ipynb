# %% [markdown]
# ### Try Model: Linear Regression

# %%
from Starts.startmodskl import *
# Out:
# local_kwargs {'nan_mean': True, 'data_path_3': '2_Titanic/data/test.csv', 'nan_drop_col': False, 'nan_zero': False, 'data_path_1': '2_Titanic/data/train.csv', 'nan_mean_neighbors': False, 'nan_drop_row': False, 'drop_obj_col': False, 'data_path_2': '2_Titanic/data/titanic_no_nan.csv'}

# %%
nonan_data.head()
# Out:
#    Survived  Pclass  Sex   Age  Ticket     Fare  Title  FamilySize
# 0         0       3    1  49.0     574   0.0000      5           0
# 1         1       2    0   7.0     571  26.2500      4           2
# 2         0       3    1  33.0     378   8.6625      5           0
# 3         0       3    1  24.0     519  24.1500      5           2
# 4         1       1    0  30.0       0  86.5000      4           0

# %%
# Choose method Linear Regression to predict the Survivors
regressor, y_true, y_pred = StartModSKL.regression_linear(nonan_data, 'Survived')

regressor
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Convert predicted value by rounding it (>0.5 will be considered as 1 else 0)
y_pred = np.array([np.round(item) for item in y_pred ])

# Compare the predicted value with true_value
len(y_true), len(y_pred)
# Out:
# (179, 179)

# %%
confusion_matrix(y_true, y_pred)
# Out:
# array([[98, 17],
#        [21, 43]])

# %% [markdown]
# ### Result:
# #### the correct predicted result 141,
# #### the wrong predicted result 38
