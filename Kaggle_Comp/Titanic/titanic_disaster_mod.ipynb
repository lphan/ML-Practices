# %%
from startmod import *
info_mod
# Out:
# {'StartMod.feature_engineering(data)': '\n        Source:\n            https://triangleinequality.wordpress.com/2013/09/08/basic-feature-engineering-with-the-titanic-data/\n\n        renew data with new_feature which has the attributes_new_feature\n        :param data:\n        :param old_feature:\n        :param new_feature:\n        :param attributes_new_feature:\n        :return: data with new feature\n        ',
#  'StartMod.feature_engineering_merge_cols(data)': '\n        merge many features into one new_feature (column)\n        :param data:\n        :param features: list of the merging features\n        :param new_feature: name of merged new_feature\n        :return: data with new column (feature)\n        ',
#  'info_help_StartMod': 'StartMod'}

# %%
attributes=['Mrs', 'Mr', 'Master', 'Miss', 'Major', 'Dr', 'Ms', 'Capt']
StartMod.feature_engineering(train_data, 'Name', 'Title', attributes_new_feature=attributes).head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Title'],
#       dtype='object')

# %%
train_data = StartMod.feature_engineering_merge_cols(train_data, ['SibSp', 'Parch'], 'FamilySize')

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Title', 'FamilySize'],
#       dtype='object')

# %%
train_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# ...

# %%
StartML.process_nan_columns(train_data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
StartML.nan_columns(train_data)
# Out:
# ['Age', 'Cabin', 'Embarked', 'Title']

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Title          878 non-null object
# FamilySize     891 non-null int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.6+ KB

# %%
StartML.get_columns_idx(train_data)
# Out:
# [('PassengerId', 0, dtype('int64')),
#  ('Survived', 1, dtype('int64')),
#  ('Pclass', 2, dtype('int64')),
#  ('Name', 3, dtype('O')),
#  ('Sex', 4, dtype('O')),
#  ('Age', 5, dtype('float64')),
#  ('Ticket', 6, dtype('O')),
#  ('Fare', 7, dtype('float64')),
#  ('Cabin', 8, dtype('O')),
#  ('Embarked', 9, dtype('O')),
#  ('Title', 10, dtype('O')),
#  ('FamilySize', 11, dtype('int64'))]

# %%
X = StartMod.encode_label_column(train_data, 'FamilySize')
type(X)
np.array_equal(X, [])
# Out:
# label_column is not valid, only accept type-object
# False

# %%
X = StartMod.encode_label_column(train_data, 'Sex')
((X[:, 4]==1.0).sum(), (X[:, 4]==0.0).sum()) == (577, 314)
# Out:
# True
