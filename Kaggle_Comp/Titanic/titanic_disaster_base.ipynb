# %%
from startml import *

# %%
info_help
# Out:
# {'StartML.kwargs': 'Show key words arguments from config.ini',
#  'StartML.nan_columns(..data..)': 'True if data has NaN value and show NaN_columns',
#  'StartML.nan_rows(..data..)': 'Show all NaN rows',
#  'StartML.operation_base(..data..)': 'Execute basic operations on data set\n',
#  'StartML.summary_base(..data..)': 'Show basic information about data set\n',
#  'info_help': 'StartML',
#  'test_data': pandas.core.frame.DataFrame,
#  'train_data': pandas.core.frame.DataFrame}

# %%
# nc = StartML.nan_columns(train_data)
StartML.summary_base(train_data)
# Out:
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
StartML.nan_columns(train_data)
# Out:
# ['Age', 'Cabin', 'Embarked']

# %%
StartML.nan_rows(train_data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 31            32         1       1
# 32            33         1       3
# ...
