# %%
from params import *
# %matplotlib inline

# %timeit hw.index
# Out:
# 145 ns ± 2.36 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit ts.index
# Out:
# 128 ns ± 10.4 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# pandas.core.series.Series
ts.plot()

# %%
# get Water level in range from 00:00 to 23:45 by day
# print (ts['1993-12-31 00:00:00':'1993-12-31 23:45:00'])
ts['1993-12-31 00:00:00':'1993-12-31 23:45:00'].plot()

# %%
# get Water level until then 
# print (ts[:'1993-12-01'])
# print (ts[:'1993-12-31 23:45:00'])
ts[:'1993-12-31 23:45:00'].plot()

# %%
# Get water level by exact timing
from datetime import datetime
# print (ts['1993-12-1'])
# print (ts[datetime(1993,12,1,18,15,0)])
ts['1993-12-1'].plot(color='blue')

# Moving Window function: shift to the right direction in 4*0.15 minutes = 1 hour
ts_lagged = ts['1993-12-1'].shift(4)
ts_lagged.plot(color = 'red')

# %%
# Plotting water level by day
day1='1993-12-1'
day2='1993-12-2'
plt.figure(figsize=(15,7))
ts[day1].plot(label=day1, color='r')
ts[day2].plot(label=day2, color='b')
plt.xlabel('Time from 0:00 to 23:45')
plt.ylabel('Water Level')
plt.legend()

# %%
# Plotting water level by month
plt.figure(figsize=(15,7))
month1 = '1993-12'
month2 = '1994-1'
plt.plot(ts[month1], label=month1, color='r')
plt.plot(ts[month2], label=month2, color='b')
plt.xlabel('Days from 0:00 to 23:45')
plt.ylabel('Water Level')
plt.legend()

# %%
# Plotting water level by year
years = ['1993', '1994', '2013', '2016']

for year in years:
    plt.figure(year)
    plt.title(year+' Water Level')
    plt.plot(ts[year], color = 'blue')    
    plt.xlabel('Date from 0:00 to 23:45')
    plt.ylabel('Water Level (in cm)')

# %%
plt.figure()
plt.title('Max and Min Water Level all years')
plt.plot(ts['1993'], color = 'blue', label='1993')    
plt.plot(ts['1994'], color = 'red', label='1994')    
plt.plot(ts['2013'], color = 'orange', label='2013')    
plt.plot(ts['2016'], color = 'green', label='2016')    
plt.xlabel('Date from 0:00 to 23:45')
plt.ylabel('Water Level (in cm)')
plt.legend()

# %%
max1993.plot(marker='x', color='r')
min1993.plot(marker='o', color='g')

max1994.plot(marker='x', color='r')
min1994.plot(marker='o', color='g')

max2013.plot(marker='x', color='r')
min2013.plot(marker='o', color='g')

max2016.plot(marker='x', color='r')
min2016.plot(marker='o', color='g')

# %% [markdown]
# ### Histogram

# %%
# By Year 1993, 1994, 2013, 2016

for year in years:
    plt.figure(year)
    plt.title('Histogram Water Level in '+year)
    plt.hist(ts[year], bins=20)
    plt.xlabel('Water Level in year')
    plt.ylabel('Frequency')

# %%
import seaborn as sns
 
for year in years:
    g = sns.PairGrid(hw[year])
    g.map_diag(plt.hist)
    g.map_offdiag(plt.scatter)

# %%
# Correlogram sns.pairplot(hw[year])  
# Reference: https://python-graph-gallery.com/110-basic-correlation-matrix-with-seaborn/
