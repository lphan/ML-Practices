# %% [markdown]
# ### Question: visualize dataset 12611-0005

# %%
# setup absolute path to location of package Starts and config-file 
from inspect import getsourcefile
import os.path as path, sys
current_dir = path.dirname(path.abspath(getsourcefile(lambda:0)))
sys.path.insert(0, current_dir[:current_dir.rfind(path.sep)])

# import package Starts
from Starts.startml import *
from Starts.startvis import *
# %matplotlib inline
marriages_1950_2015 = train_data
marriages_groupby_age2015 = nonan_data
marriages_groupby_de_1994_2015 = test_data
# Out:
# local_kwargs {'data_path_1': './data/marriages_1950_2015.csv', 'data_path_2': './data/marriages_groupby_age2015.csv', 'data_path_3': './data/marriages_groupby_de_1994_2015.csv', 'drop_obj_col': False, 'nan_drop_col': False, 'nan_drop_row': False, 'nan_zero': False, 'nan_mean': True, 'nan_mean_neighbors': False}

# %%
len(marriages_groupby_age2015.columns), len(marriages_groupby_age2015), marriages_groupby_age2015['unter 15 Jahre'][0]
# Out:
# (14, 14, '-')

# %%
# Replace all values with '-' by 0
marriages_groupby_age2015.replace(to_replace='-', value=0, inplace=True)
marriages_groupby_age2015['Husband_Age'] = marriages_groupby_age2015.columns
marriages_groupby_age2015.set_index('Husband_Age', inplace=True)

# %%
marriages_groupby_age2015 = marriages_groupby_age2015.apply(pd.to_numeric)

# %%
type(marriages_groupby_age2015['15 bis unter 20 Jahre'].iloc[1])
# Out:
# numpy.int64

# %%
marriages_groupby_age2015
# Out:
#                        unter 15 Jahre  15 bis unter 20 Jahre  \
# Husband_Age
# unter 15 Jahre                      0                      0
# 15 bis unter 20 Jahre               0                    353
# 20 bis unter 25 Jahre               0                   1986
# 25 bis unter 30 Jahre               0                    917
# 30 bis unter 35 Jahre               0                    194
# 35 bis unter 40 Jahre               0                     51
# 40 bis unter 45 Jahre               0                     18
# 45 bis unter 50 Jahre               0                     19
# 50 bis unter 55 Jahre               0                      9
# 55 bis unter 60 Jahre               0                      3
# 60 bis unter 65 Jahre               0                      1
# 65 bis unter 70 Jahre               0                      0
# 70 bis unter 75 Jahre               0                      0
# 75 Jahre und mehr                   0                      0
#
# ...

# %%
marriages_groupby_age2015.columns
# Out:
# Index(['unter 15 Jahre', '15 bis unter 20 Jahre', '20 bis unter 25 Jahre',
#        '25 bis unter 30 Jahre', '30 bis unter 35 Jahre',
#        '35 bis unter 40 Jahre', '40 bis unter 45 Jahre',
#        '45 bis unter 50 Jahre', '50 bis unter 55 Jahre',
#        '55 bis unter 60 Jahre', '60 bis unter 65 Jahre',
#        '65 bis unter 70 Jahre', '70 bis unter 75 Jahre', '75 Jahre und mehr'],
#       dtype='object')

# %%
rcParams['figure.figsize'] = 15, 6
for column in marriages_groupby_age2015.columns:
    marriages_groupby_age2015[column].plot.bar()
    plt.xlabel('Husband_Age')
    plt.ylabel('Frequency/ Statistics')
    plt.ylim(ymin=0) # value starts at 0
    plt.xticks(rotation=45)
    plt.title('Age of Wife: '+str(column))
    plt.legend()
    plt.show()
