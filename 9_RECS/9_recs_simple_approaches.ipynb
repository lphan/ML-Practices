# %% [markdown]
# ### Analyse restaurant & consumer data Data Set
# ### Recommending based on counts (number of ratings)

# %%
# setup absolute path to location of package Starts and config-file 
from inspect import getsourcefile
import os.path as path, sys
current_dir = path.dirname(path.abspath(getsourcefile(lambda:0)))
sys.path.insert(0, current_dir[:current_dir.rfind(path.sep)])

# import package Starts
from Starts.startml import *
from Starts.startvis import *
rcParams['figure.figsize'] = 20, 6
# Out:
# local_kwargs {'data_path': './data/rating_final.csv, ./data/chefmozcuisine.csv', 'drop_obj_col': False, 'nan_drop_col': False, 'nan_drop_row': False, 'nan_zero': False, 'nan_mean': True, 'nan_mean_neighbors': False}

# %%
ratingfinal = idata[0]
cuisine = idata[1]

# %%
ratingfinal.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
cuisine.head()
# Out:
#    placeID        Rcuisine
# 0   135110         Spanish
# 1   135109         Italian
# 2   135107  Latin_American
# 3   135106         Mexican
# 4   135105       Fast_Food

# %%
# Find Rcuisine with max counted values
StartML.findMaxMinValueDict(StartML.countby_values(cuisine['Rcuisine']), ma=True)
# Out:
# {'Mexican': 239}

# %%
# Find Rcuisine with min counted values
StartML.findMaxMinValueDict(StartML.countby_values(cuisine['Rcuisine']), ma=False)
# Out:
# {'Afghan': 1,
#  'Bagels': 1,
#  'Brazilian': 1,
#  'California': 1,
#  'Caribbean': 1,
#  'Ethiopian': 1,
#  'Fine_Dining': 1,
#  'Korean': 1,
#  'Mongolian': 1,
#  'Organic-Healthy': 1,
#  'Persian': 1,
#  'Soup': 1,
#  'Southern': 1,
#  'Thai': 1,
#  'Turkish': 1}

# %%
cuisine['Rcuisine'].describe()
# Out:
# count         916
# unique         59
# top       Mexican
# freq          239
# Name: Rcuisine, dtype: object

# %%
StartVis.vis_bar(cuisine, ['Rcuisine'], rot=45, bar=True)
