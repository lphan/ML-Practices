# %% [markdown]
# ### COVID-19
# ### Comparision of total cases in first group and second group countries, and the USA

# %%
from covid import *
# %matplotlib inline
# Out:
# Start importing World-data  ./COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/
# Start importing USA-data  ./COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/
# Start importing single data  ./COVID-19/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv
# Start importing single data  ./COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# Start importing single data  ./COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# Start importing single data  ./COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv
# /home/edvs1/lphan/.conda/envs/aic/lib/python3.7/site-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %% [markdown]
# ### Number of covid-19 outbreak days

# %%
rcParams['figure.figsize'] = 20, 6
len(data)
# Out:
# 381

# %%
updated_date=files[-1].split('.')[0]
updated_date
# Out:
# '02-05-2021'

# %% [markdown]
# ### Countries: First group vs Second Group

# %%
print("First group (Scandinavia countries): ", first_group)
print("Second group (ASIA countries): ", second_group)
# Out:
# First group (Scandinavia countries):  ['Italy', 'Germany', 'Spain', 'France', 'United Kingdom', 'Switzerland', 'Netherlands', 'Austria', 'Belgium', 'Luxembourg']
# Second group (ASIA countries):  ['China', 'Korea, South', 'Japan', 'Malaysia', 'Indonesia', 'Thailand', 'Philippines', 'Singapore', 'Taiwan*', 'Vietnam']

# %% [markdown]
# ### Comparison total CONFIRMED

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 10))
plt.plot(x_dat, firstgroup_total, color='orange', label='Confirmed_FirstGroup')
plt.plot(x_dat, firstgroup_total, 'orange', marker='.')
plt.plot(x_dat, secondgroup_total, color='blue', label='Confirmed_SecondGroup')
plt.plot(x_dat, secondgroup_total, 'blue', marker='.')
plt.plot(x_dat, y_dat_confirmed['US'], color='red', label='Confirmed_US')
plt.plot(x_dat, y_dat_confirmed['US'], 'red', marker='.')
plt.xlabel('Days')
plt.ylabel('Confirmed')
plt.legend()

print("In FirstGroup countries -- total confirmed: ", firstgroup_total[-1], ", new confirmed last day: ", firstgroup_total[-1]-firstgroup_total[-2], ", total population: ", int(sum(first_group_population)), "ratio: ", firstgroup_total[-1]/int(sum(first_group_population)))
print("\nIn SecondGroup countries --  total confirmed: ", secondgroup_total[-1], ", new confirmed last day: ", secondgroup_total[-1]-secondgroup_total[-2], ", total population: ", int(sum(second_group_population)), "ratio: ", secondgroup_total[-1]/int(sum(second_group_population)))
print("\nIn the USA -- total confirmed: ", y_dat_confirmed['US'][-1], ", new confirmed last day: ", y_dat_confirmed['US'][-1]-y_dat_confirmed['US'][-2], ", total population: ", int(country_pop_dict['US']), "ratio: ", y_dat_confirmed['US'][-1]/int(country_pop_dict['US']))
# Out:
# In FirstGroup countries -- total confirmed:  17846250 , new confirmed last day:  128531 , total population:  371171555 ratio:  0.04808086654161847
#
# In SecondGroup countries --  total confirmed:  2571697 , new confirmed last day:  20961 , total population:  2194698354 ratio:  0.0011717769757802444
#
# In the USA -- total confirmed:  26813772 , new confirmed last day:  133558 , total population:  329466283 ratio:  0.0813854812572733

# %% [markdown]
# ### Comparison total FATALITIES

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 10))
plt.plot(x_dat, firstgroup_deaths_total, color='orange', label='Fatalities_FirstGroup')
plt.plot(x_dat, firstgroup_deaths_total, 'orange', marker='.')
plt.plot(x_dat, secondgroup_deaths_total, color='blue', label='Fatalities_SecondGroup')
plt.plot(x_dat, secondgroup_deaths_total, 'blue', marker='.')
plt.plot(x_dat, y_dat_deaths['US'], color='red', label='Fatalities_US')
plt.plot(x_dat, y_dat_deaths['US'], 'red', marker='.')
plt.xlabel('Days')
plt.ylabel('Fatalities')
plt.legend()

print("In Firstgroup countries -- total fatalities:  ", firstgroup_deaths_total[-1], ", new fatalities last day: ", firstgroup_deaths_total[-1]-firstgroup_deaths_total[-2], ", total population: ", int(sum(first_group_population)), "ratio: ", firstgroup_deaths_total[-1]/firstgroup_total[-1])
print("\nIn Secondgroup countries -- total fatalities: ", secondgroup_deaths_total[-1], ", new fatalities last day: ", secondgroup_deaths_total[-1]-secondgroup_deaths_total[-2], ", total population: ", int(sum(second_group_population)), "ratio: ", secondgroup_deaths_total[-1]/secondgroup_total[-1])
print("\nIn the USA -- total fatalities:  ", y_dat_deaths['US'][-1], ", new fatalities last day: ", y_dat_deaths['US'][-1]-y_dat_deaths['US'][-2], ", total population: ", int(country_pop_dict['US']), "ratio: ", y_dat_deaths['US'][-1]/int(country_pop_dict['US']))
# Out:
# In Firstgroup countries -- total fatalities:   457403 , new fatalities last day:  3837 , total population:  371171555 ratio:  0.025630202423478323
#
# In Secondgroup countries -- total fatalities:  55821 , new fatalities last day:  392 , total population:  2194698354 ratio:  0.02170590081179859
#
# In the USA -- total fatalities:   459555 , new fatalities last day:  3674 , total population:  329466283 ratio:  0.001394846828681404

# %% [markdown]
# ### Comparison total Recovered

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 10))
plt.plot(x_dat, firstgroup_rec_total, color='orange', label='Recovered_FirstGroup')
plt.plot(x_dat, firstgroup_rec_total, 'orange', marker='.')
plt.plot(x_dat, secondgroup_rec_total, color='blue', label='Recovered_SecondGroup')
plt.plot(x_dat, secondgroup_rec_total, 'blue', marker='.')
plt.plot(x_dat, y_dat_recovered['US'], color='red', label='Recovered_US')
plt.plot(x_dat, y_dat_recovered['US'], 'red', marker='.')
plt.xlabel('Days')
plt.ylabel('Recovered')
plt.legend()

print("In Firstgroup countries -- total recovered: ", firstgroup_rec_total[-1], ", new recovered last day: ", firstgroup_rec_total[-1]-firstgroup_rec_total[-2], ", total population: ", int(sum(first_group_population)), "ratio: ", firstgroup_rec_total[-1]/firstgroup_total[-1])
print("\nIn Secondgroup countries -- total recovered: ", secondgroup_rec_total[-1], ", new recovered last day: ", secondgroup_rec_total[-1]-secondgroup_rec_total[-2], ", total population: ", int(sum(second_group_population)), "ratio: ", secondgroup_rec_total[-1]/secondgroup_total[-1])
print("\nIn the USA -- total recovered: ", y_dat_recovered['US'][-1], ", new recovered last day: ", y_dat_recovered['US'][-1]-y_dat_recovered['US'][-2], ", total population: ", int(country_pop_dict['US']), "ratio: ", y_dat_recovered['US'][-1]/int(country_pop_dict['US']))
# Out:
# In Firstgroup countries -- total recovered:  5301884 , new recovered last day:  32611 , total population:  371171555 ratio:  0.2970867269034111
#
# In Secondgroup countries -- total recovered:  2196913 , new recovered last day:  20592 , total population:  2194698354 ratio:  0.854265879689559
#
# In the USA -- total recovered:  11030782.0 , new recovered last day:  59034.0 , total population:  329466283 ratio:  0.03348076136822778
