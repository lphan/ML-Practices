# %% [markdown]
# ### COVID-19
# ### Comparision of total cases in 10 Europe countries, 10 Asia countries and the USA

# %%
# Configuration: setup absolute path to location of package Starts and config-file 
from inspect import getsourcefile
import os.path as path, sys
current_dir = path.dirname(path.abspath(getsourcefile(lambda:0)))
sys.path.insert(0, current_dir[:current_dir.rfind(path.sep)])

from Starts.start import *
from Starts.startml import *
from Starts.startvis import *  
# %matplotlib inline
rcParams['figure.figsize'] = 20, 6
# Out:
# C:\Users\lphan\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# Using TensorFlow backend.
# C:\Users\lphan\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...

# %% [markdown]
# ### Number of covid-19 outbreak days

# %%
from covid import *
len(data)
# Out:
# C:\Users\lphan\Anaconda3\lib\site-packages\pandas\core\strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# 112

# %% [markdown]
# ### 10 EU_countries and 10 ASIA_countries

# %%
print(eu10_countries)
print(asia10_countries)
# Out:
# ['Italy', 'Germany', 'Spain', 'France', 'United Kingdom', 'Switzerland', 'Netherlands', 'Austria', 'Belgium', 'Norway']
# ['China', 'Korea, South', 'Japan', 'Malaysia', 'Indonesia', 'Thailand', 'Philippines', 'Singapore', 'Taiwan*', 'Vietnam']

# %% [markdown]
# ### Comparison total CONFIRMED (last day) in 10 EU_countries, 10 ASIA_countries, and the USA

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.plot(x_dat, asia_total, color='blue', label='Confirmed_ASIA')
plt.plot(x_dat, asia_total, 'ob')
plt.plot(x_dat, eu_total, color='orange', label='Confirmed_EU')
plt.plot(x_dat, eu_total, 'og')
plt.plot(x_dat, y_dat_confirmed['US'], color='red', label='Confirmed_US')
plt.plot(x_dat, y_dat_confirmed['US'], 'or')
plt.xlabel('Days')
plt.ylabel('Confirmed')
plt.legend()

print("In 10 ASIA countries: ", asia_total[-1], ", last day increasing: ", asia_total[-1]-asia_total[-2], ", total population: ", int(sum(asia10_population)))
print("In 10 Europe countries: ", eu_total[-1], ", last day increasing: ", eu_total[-1]-eu_total[-2], ", total population: ", int(sum(eu10_population)))
print("In the USA: ", y_dat_confirmed['US'][-1], ", last day increasing: ", y_dat_confirmed['US'][-1]-y_dat_confirmed['US'][-2], ", total population: ", int(country_pop_dict['US']))
# Out:
# In 10 ASIA countries:  172205 , last day increasing:  1769 , total population:  2194698354
# In 10 Europe countries:  1179967 , last day increasing:  7468 , total population:  375966821
# In the USA:  1369574 , last day increasing:  21693 , total population:  329466283

# %% [markdown]
# ### Comparison total FATALITIES (last day) in 10 EU_countries, 10 ASIA_countries, and the USA

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.plot(x_dat, asia_deaths_total, color='blue', label='Fatalities_ASIA')
plt.plot(x_dat, asia_deaths_total, 'ob')
plt.plot(x_dat, eu_deaths_total, color='orange', label='Fatalities_EU')
plt.plot(x_dat, eu_deaths_total, 'og')
plt.plot(x_dat, y_dat_deaths['US'], color='red', label='Fatalities_US')
plt.plot(x_dat, y_dat_deaths['US'], 'or')
plt.xlabel('Days')
plt.ylabel('Fatalities')
plt.legend()

print("In 10 ASIA countries: ", asia_deaths_total[-1], ", last day increasing: ", asia_deaths_total[-1]-asia_deaths_total[-2], ", total population: ", int(sum(asia10_population)))
print("In 10 Europe countries: ", eu_deaths_total[-1], ", last day increasing: ", eu_deaths_total[-1]-eu_deaths_total[-2], ", total population: ", int(sum(eu10_population)))
print("In the USA: ", y_dat_deaths['US'][-1], ", last day increasing: ", y_dat_deaths['US'][-1]-y_dat_deaths['US'][-2], ", total population: ", int(country_pop_dict['US']))
# Out:
# In 10 ASIA countries:  7504 , last day increasing:  66 , total population:  2194698354
# In 10 Europe countries:  142340 , last day increasing:  1538 , total population:  375966821
# In the USA:  82376 , last day increasing:  1694 , total population:  329466283

# %% [markdown]
# ### Comparison total Recovered (last day) in 10 EU_countries, 10 ASIA_countries, and the USA

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.plot(x_dat, asia_rec_total, color='blue', label='Recovered_ASIA')
plt.plot(x_dat, asia_rec_total, 'ob')
plt.plot(x_dat, eu_rec_total, color='orange', label='Recovered_EU')
plt.plot(x_dat, eu_rec_total, 'og')
plt.plot(x_dat, y_dat_recovered['US'], color='red', label='Recovered_US')
plt.plot(x_dat, y_dat_recovered['US'], 'or')
plt.xlabel('Days')
plt.ylabel('Recovered')
plt.legend()

print("In 10 ASIA countries: ", asia_rec_total[-1], ", last day increasing: ", asia_rec_total[-1]-asia_rec_total[-2], ", total population: ", int(sum(asia10_population)))
print("In 10 Europe countries: ", eu_rec_total[-1], ", last day increasing: ", eu_rec_total[-1]-eu_rec_total[-2], ", total population: ", int(sum(eu10_population)))
print("In the USA: ", y_dat_recovered['US'][-1], ", last day increasing: ", y_dat_recovered['US'][-1]-y_dat_recovered['US'][-2], ", total population: ", int(country_pop_dict['US']))
# Out:
# In 10 ASIA countries:  115113 , last day increasing:  1321 , total population:  2194698354
# In 10 Europe countries:  509001 , last day increasing:  7069 , total population:  375966821
# In the USA:  230287 , last day increasing:  -2446 , total population:  329466283
