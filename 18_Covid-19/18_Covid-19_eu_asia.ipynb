# %% [markdown]
# ### COVID-19
# ### Comparision of total cases in 10 Europe countries, 10 Asia countries and the USA

# %%
# Configuration: setup absolute path to location of package Starts and config-file 
from inspect import getsourcefile
import os.path as path, sys
current_dir = path.dirname(path.abspath(getsourcefile(lambda:0)))
sys.path.insert(0, current_dir[:current_dir.rfind(path.sep)])

from Starts.start import *
from Starts.startml import *
from Starts.startvis import *  
# %matplotlib inline
rcParams['figure.figsize'] = 20, 6
# Out:
# C:\Users\Duc-LongPhan\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# Using TensorFlow backend.
# Start importing folder
# ...

# %% [markdown]
# ### Number of covid-19 outbreak days

# %%
from covid import *
len(data)
# Out:
# 81

# %% [markdown]
# ### 10 EU_countries and 10 ASIA_countries

# %%
print(eu_10_countries)
print(asia_10countries)
# Out:
# ['Italy', 'Germany', 'Spain', 'France', 'United Kingdom', 'Switzerland', 'Netherlands', 'Austria', 'Belgium', 'Norway']
# ['China', 'Korea', 'Japan', 'Malaysia', 'Indonesia', 'Thailand', 'Philippines', 'Singapore', 'Taiwan', 'Vietnam']

# %% [markdown]
# ### Comparison total infected cases (last day) in 10 EU_countries, 10 ASIA_countries, and the USA

# %%
# Todo: bar_chart
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.plot(x_dat, asia_total, color='blue', label='Confirmed_ASIA')
plt.plot(x_dat, asia_total, 'ob')
plt.plot(x_dat, eu_total, color='orange', label='Confirmed_EU')
plt.plot(x_dat, eu_total, 'og')
plt.plot(x_dat, y_dat_us, color='red', label='Confirmed_US')
plt.plot(x_dat, y_dat_us, 'or')
plt.xlabel('Days')
plt.ylabel('Confirmed')
plt.legend()

print("In 10 ASIA countries: ", asia_total[-1], ", last day increasing: ", asia_total[-1]-asia_total[-2])
print("In 10 Europe countries: ", eu_total[-1], ", last day increasing: ", eu_total[-1]-eu_total[-2])
print("In the USA: ", y_dat_us[-1], ", last day increasing: ", y_dat_us[-1]-y_dat_us[-2])
# Out:
# In 10 ASIA countries:  117759 , last day increasing:  1565
# In 10 Europe countries:  748718 , last day increasing:  25825
# In the USA:  526396 , last day increasing:  29861

# %% [markdown]
# ### Comparison total Fatalities (last day) in 10 EU_countries, 10 ASIA_countries, and the USA

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.plot(x_dat, asia_deaths_total, color='blue', label='Fatalities_ASIA')
plt.plot(x_dat, asia_deaths_total, 'ob')
plt.plot(x_dat, eu_deaths_total, color='orange', label='Fatalities_EU')
plt.plot(x_dat, eu_deaths_total, 'og')
plt.plot(x_dat, y_dat_death_us, color='red', label='Fatalities_US')
plt.plot(x_dat, y_dat_death_us, 'or')
plt.xlabel('Days')
plt.ylabel('Fatalities')
plt.legend()

print("In 10 ASIA countries: ", asia_deaths_total[-1], ", last day increasing: ", asia_deaths_total[-1]-asia_deaths_total[-2])
print("In 10 Europe countries: ", eu_deaths_total[-1], ", last day increasing: ", eu_deaths_total[-1]-eu_deaths_total[-2])
print("In the USA: ", y_dat_death_us[-1], ", last day increasing: ", y_dat_death_us[-1]-y_dat_death_us[-2])
# Out:
# In 10 ASIA countries:  4349 , last day increasing:  59
# In 10 Europe countries:  70044 , last day increasing:  3185
# In the USA:  20463 , last day increasing:  1877

# %% [markdown]
# ### Comparison total Recovered (last day) in 10 EU_countries, 10 ASIA_countries, and the USA

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.plot(x_dat, asia_rec_total, color='blue', label='Recovered_ASIA')
plt.plot(x_dat, asia_rec_total, 'ob')
plt.plot(x_dat, eu_rec_total, color='orange', label='Recovered_EU')
plt.plot(x_dat, eu_rec_total, 'og')
plt.plot(x_dat, y_dat_recovered_us, color='red', label='Recovered_US')
plt.plot(x_dat, y_dat_recovered_us, 'or')
plt.xlabel('Days')
plt.ylabel('Recovered')
plt.legend()

print("In 10 ASIA countries: ", asia_rec_total[-1], ", last day increasing: ", asia_rec_total[-1]-asia_rec_total[-2])
print("In 10 Europe countries: ", eu_rec_total[-1], ", last day increasing: ", eu_rec_total[-1]-eu_rec_total[-2])
print("In the USA: ", y_dat_recovered_us[-1], ", last day increasing: ", y_dat_recovered_us[-1]-y_dat_recovered_us[-2])
# Out:
# In 10 ASIA countries:  90226 , last day increasing:  641
# In 10 Europe countries:  201341 , last day increasing:  12471
# In the USA:  31270 , last day increasing:  2480
