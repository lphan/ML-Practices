# %% [markdown]
# ### COVID-19
# ### USA - UPDATE by DAY

# %%
from covid_import import *
from vaccine_import import *
# %matplotlib inline
# Out:
# Start importing World-data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/
# Start importing USA-data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/
# Start importing single data  ./data/COVID-19/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv
# Start importing single data vaccine in US ./data/Vaccine/COVID-19/data_tables/vaccine_data/us_data/time_series/vaccine_data_us_timeline.csv
# Start importing single data vaccine in the World ./data/Vaccine/COVID-19/data_tables/vaccine_data/global_data/vaccine_data_global.csv
# Start importing time series data vaccine in the World ./data/Vaccine/COVID-19/data_tables/vaccine_data/global_data/time_series_covid19_vaccine_global.csv

# %%
rcParams['figure.figsize'] = 20, 6
len(data_us)
# Out:
# 476

# %% [markdown]
# ### Update Data in USA changed from 12.04.2020

# %%
data_date = np.unique(data_us[-1]['Last_Update'])[0]
data_date
# Out:
# '2021-08-01 04:30:43'

# %%
total_confirmed_us = [sum(data_us[i]['Confirmed']) for i in range(len(data_us))]
total_fatalities_us = [sum(data_us[i]['Deaths']) for i in range(len(data_us))]
total_recovered_us = [sum(data_us[i]['Recovered']) for i in range(len(data_us))]

plt.bar(np.arange(len(data_us)), total_confirmed_us, color='orange')
plt.bar(np.arange(len(data_us)), total_recovered_us, color='green')
plt.bar(np.arange(len(data_us)), total_fatalities_us, color='red')
plt.title("Total Confirmed/Deaths/Recovered cases at day %s "% data_date)
plt.xlabel("Day 0 start at day %s"%files_us[0])
plt.ylabel("Total Number of Confirmed/ Deaths/ Recovered Cases by day")

print("Total Confirmed: ", total_confirmed_us[-1])
print("Total Fatalities: ", total_fatalities_us[-1])
print("Total Recovered: ", total_recovered_us[-1])
print("Remaining: ", total_confirmed_us[-1]-total_fatalities_us[-1]-total_recovered_us[-1])
print("New Cases Confirmed: ", total_confirmed_us[-1]-total_confirmed_us[-2])
print("New Cases Fatalities: ", total_fatalities_us[-1]-total_fatalities_us[-2])
print("New Cases Recovered: ", total_recovered_us[-1]-total_recovered_us[-2])
# Out:
# Total Confirmed:  34978276
# Total Fatalities:  613157
# Total Recovered:  0.0
# Remaining:  34365119.0
# New Cases Confirmed:  32808
# New Cases Fatalities:  144
# New Cases Recovered:  0.0

# %%
data_us[-1].sort_values(by='Confirmed', ascending=False)
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 5                 California             US  2021-08-01 04:30:43  36.1162
# 49                     Texas             US  2021-08-01 04:30:43  31.0545
# 11                   Florida             US  2021-08-01 04:30:43  27.7663
# 36                  New York             US  2021-08-01 04:30:43  42.1657
# 17                  Illinois             US  2021-08-01 04:30:43  40.3495
# 43              Pennsylvania             US  2021-08-01 04:30:43  40.5908
# 12                   Georgia             US  2021-08-01 04:30:43  33.0406
# 40                      Ohio             US  2021-08-01 04:30:43  40.3888
# 37            North Carolina             US  2021-08-01 04:30:43  35.6301
# 34                New Jersey             US  2021-08-01 04:30:43  40.2989
# 26                  Michigan             US  2021-08-01 04:30:43  43.3266
# 3                    Arizona             US  2021-08-01 04:30:43  33.7298
# 48                 Tennessee             US  2021-08-01 04:30:43  35.7478
# 18                   Indiana             US  2021-08-01 04:30:43  39.8494
# 25             Massachusetts             US  2021-08-01 04:30:43  42.2302
# 53                  Virginia             US  2021-08-01 04:30:43  37.7693
# 56                 Wisconsin             US  2021-08-01 04:30:43  44.2685
# 29                  Missouri             US  2021-08-01 04:30:43  38.4561
# 46            South Carolina             US  2021-08-01 04:30:43  33.8569
# 27                 Minnesota             US  2021-08-01 04:30:43  45.6945
# 0                    Alabama             US  2021-08-01 04:30:43  32.3182
# 6                   Colorado             US  2021-08-01 04:30:43  39.0598
0
#
#    ISO3   Testing_Rate  Hospitalization_Rate
# 5   USA  186187.671597                   0.0
# 49  USA   92818.900726                   0.0
# 11  USA  113305.484651                   0.0
# 36  USA  314275.299006                   0.0
# 17  USA  211678.826587                   0.0
# 43  USA  117532.525610                   0.0
# 12  USA   89311.879163                   0.0
# 40  USA  120271.312590                   0.0
# 37  USA  123161.170334                   0.0
# 34  USA  166472.018725                   0.0
# 26  USA  146253.200582                   0.0
# 3   USA  147188.165167                   0.0
# 48  USA  123324.343471                   0.0
# 18  USA  166741.619665                   0.0
# 25  USA  357510.109172                   0.0
# 53  USA   93417.881209                   0.0
# 56  USA  160009.405001                   0.0
# 29  USA   98839.644229                   0.0
# 46  USA  133834.138000                   0.0
# 27  USA  172215.438880                   0.0
# 0   USA   56219.253404                   0.0
# 6   USA  164384.024550                   0.0
# 22  USA  162963.641753                   0.0
# 21  USA  126716.682264                   0.0
# 41  USA  106567.776211                   0.0
# 54  USA  115925.857396                   0.0
# 24  USA  186328.733906                   0.0
# 50  USA  115718.203420                   0.0
# 4   USA  109683.001282                   0.0
# 19  USA   48198.772135                   0.0
# 32  USA  120860.696666                   0.0
# 7   USA  254032.031643                   0.0
# 28  USA   68753.378947                   0.0
# 20  USA   51468.087546                   0.0
# 31  USA  162577.801581                   0.0
# 42  USA  135202.076374                   0.0
# 35  USA  181658.065584                   0.0
# 16  USA   46211.413687                   0.0
# 55  USA  176149.947521                   0.0
# 45  USA  435386.803932                   0.0
# 44  PRI   13015.147976                   0.0
# 47  USA   94844.680267                   0.0
# 30  USA  141668.990193                   0.0
# 38  USA  210995.562041                   0.0
# 8   USA  200307.774779                   0.0
# 33  USA  156789.273603                   0.0
# 1   USA  341195.825274                   0.0
# 23  USA  179872.371322                   0.0
# 57  USA  141679.179071                   0.0
# 10  USA  245237.754499                   0.0
# 15  USA  130357.617073                   0.0
# 51  USA  284643.158774                   0.0
# 14  GUM  106961.620664                   0.0
# 52  VIR  134891.113846                   0.0
# 39  MNP   31811.257798                   0.0
# 13  USA       0.000000                   0.0
# 9   USA       0.000000                   0.0
# 2   ASM    3846.084722                   0.0

# %%
# Confirmed
data_us[-1].sort_values('Confirmed', ascending=False).head(10)[['Province_State', 'Confirmed']].set_index(keys=['Province_State']).plot(kind='bar', color='orange', rot=0)
data_us[-1].sort_values('Confirmed', ascending=False).head(10)[['Province_State', 'Confirmed']].set_index(keys=['Province_State'])
# Out:
#                 Confirmed
# Province_State
# California        3961190
# Texas             3138837
# Florida           2634234
# New York          2150390
# Illinois          1419611
# Pennsylvania      1229002
# Georgia           1179449
# Ohio              1129277
# North Carolina    1048076
# New Jersey        1039353

# %%
# Fatalities
data_us[-1].sort_values('Deaths', ascending=False).head(10)[['Province_State', 'Deaths']].set_index(keys=['Province_State']).plot(kind='bar', color='red', rot=0)
data_us[-1].sort_values('Deaths', ascending=False).head(10)[['Province_State', 'Deaths']].set_index(keys=['Province_State'])
# Out:
#                 Deaths
# Province_State
# California       64425
# New York         53641
# Texas            53277
# Florida          39079
# Pennsylvania     27850
# New Jersey       26602
# Illinois         25873
# Georgia          21676
# Michigan         21188
# Ohio             20492

# %%
data_us[-1].sort_values('Case_Fatality_Ratio', ascending=False).head(10)[['Province_State', 'Case_Fatality_Ratio']].set_index(keys=['Province_State']).plot(kind='bar', color='red', rot=0)
data_us[-1].sort_values('Case_Fatality_Ratio', ascending=False).head(10)[['Province_State', 'Case_Fatality_Ratio']].set_index(keys=['Province_State'])
# Out:
#                       Case_Fatality_Ratio
# Province_State
# Grand Princess                   2.912621
# New Jersey                       2.559477
# Massachusetts                    2.512156
# New York                         2.494478
# Connecticut                      2.340441
# District of Columbia             2.279852
# Pennsylvania                     2.266066
# Mississippi                      2.195892
# Maryland                         2.096904
# New Mexico                       2.095848

# %%
# Recovered
data_us[-1].sort_values('Recovered', ascending=False).head(10)[['Province_State', 'Recovered']].set_index(keys=['Province_State']).plot(kind='bar', color='green', rot=0)
data_us[-1].sort_values('Recovered', ascending=False).head(10)[['Province_State', 'Recovered']].set_index(keys=['Province_State'])
# Out:
#                 Recovered
# Province_State
# Alabama               0.0
# Pennsylvania          0.0
# Nebraska              0.0
# Nevada                0.0
# New Hampshire         0.0
# New Jersey            0.0
# New Mexico            0.0
# New York              0.0
# North Carolina        0.0
# North Dakota          0.0

# %%
states_vaccine = total_confirmed_vaccine_us.groupby(['Province_State']).sum()
states_vaccine
# Out:
#                    FIPS         Lat        Long_   Doses_alloc  Doses_shipped  \
# Province_State
# Alabama          1217.0  39331.2494 -105760.0991  5.009630e+07   1.264846e+09
# Alaska           2456.0  75363.2196 -187152.6032  1.544741e+08   2.384588e+08
# American Samoa  70740.0 -16825.5090 -200585.6280  3.853700e+06   1.695481e+07
# Arizona          4704.0  39666.2448 -131043.0912  1.255710e+08   2.015996e+09
# Arkansas         5875.0  41089.3975 -108538.3925  6.876098e+07   7.766089e+08
# ...                 ...         ...          ...           ...            ...
# Virginia        62067.0  45965.2381  -95132.8900  8.483380e+07   2.588612e+09
# Washington      62275.0  55696.0575 -142751.3375  7.782990e+07   2.306700e+09
# West Virginia   63666.0  45381.1248  -95445.3555  3.355694e+07   5.092147e+08
# Wisconsin       64680.0  52059.7560 -105389.0040  1.547372e+09   1.579259e+09
# Wyoming         68152.0  52034.0520 -130587.1425  5.654575e+06   1.489715e+08
#
#                  Doses_admin  Stage_One_Doses  Stage_Two_Doses
# Province_State
# Alabama         8.426327e+08     5.040795e+08      342157488.0
# Alaska          1.834060e+08     1.035779e+08       77907298.0
# American Samoa  1.268426e+07     7.311149e+06        5392900.0
# Arizona         1.635203e+09     9.474174e+08      642410855.0
# Arkansas        5.694895e+08     3.352594e+08      222687377.0
# ...                      ...              ...              ...
# Virginia        2.192702e+09     1.285692e+09      890676326.0
# Washington      1.969515e+09     1.143328e+09      806768105.0
# West Virginia   4.049938e+08     2.262635e+08      161021323.0
# Wisconsin       1.451129e+09     8.186307e+08      600933074.0
# Wyoming         1.139681e+08     6.457087e+07       46600502.0
#
# [65 rows x 8 columns]

# %%
states_vaccine.loc['California']
# Out:
# FIPS               6.936000e+03
# Lat                4.175033e+04
# Long_             -1.383519e+05
# Doses_alloc        9.377328e+08
# Doses_shipped      1.218349e+10
# Doses_admin        9.922026e+09
# Stage_One_Doses    5.912723e+09
# Stage_Two_Doses    3.827985e+09
# Name: California, dtype: float64

# %%
states_vaccine['Doses_alloc'].sort_values(ascending=False).plot(kind='bar')
# plt.xticks(rotation=60)
states_vaccine['Doses_alloc']
# Out:
# Province_State
# Alabama           5.009630e+07
# Alaska            1.544741e+08
# American Samoa    3.853700e+06
# Arizona           1.255710e+08
# Arkansas          6.876098e+07
#                       ...
# Virginia          8.483380e+07
# Washington        7.782990e+07
# West Virginia     3.355694e+07
# Wisconsin         1.547372e+09
# Wyoming           5.654575e+06
# Name: Doses_alloc, Length: 65, dtype: float64

# %%
states_vaccine['Doses_admin'].sort_values(ascending=False).plot(kind='bar')
# plt.xticks(rotation=60)
states_vaccine['Doses_admin']
# Out:
# Province_State
# Alabama           8.426327e+08
# Alaska            1.834060e+08
# American Samoa    1.268426e+07
# Arizona           1.635203e+09
# Arkansas          5.694895e+08
#                       ...
# Virginia          2.192702e+09
# Washington        1.969515e+09
# West Virginia     4.049938e+08
# Wisconsin         1.451129e+09
# Wyoming           1.139681e+08
# Name: Doses_admin, Length: 65, dtype: float64

# %%
# states_vaccine.iloc('California')
states_vaccine['Stage_Two_Doses'].sort_values(ascending=False).plot(kind='bar')
# plt.xticks(rotation=60)
states_vaccine['Stage_Two_Doses']
# Out:
# Province_State
# Alabama           342157488.0
# Alaska             77907298.0
# American Samoa      5392900.0
# Arizona           642410855.0
# Arkansas          222687377.0
#                      ...
# Virginia          890676326.0
# Washington        806768105.0
# West Virginia     161021323.0
# Wisconsin         600933074.0
# Wyoming            46600502.0
# Name: Stage_Two_Doses, Length: 65, dtype: float64

# %%
# Try getting recovered data
# Source: https://covidtracking.com/data/api
us_api = 'https://api.covidtracking.com/v1/us/current.json'

import requests
response = requests.get(us_api)
if response.status_code != 200:
    print('Failed to get data:', response.status_code)
else:
    print('First 100 characters of data are')
    print(response.text[:100])
# Out:
# First 100 characters of data are
# [{"date":20210307,"states":56,"positive":28756489,"negative":74582825,"pending":11808,"hospitalizedC

# %%
response.json()
# Out:
# [{'date': 20210307,
#   'states': 56,
#   'positive': 28756489,
#   'negative': 74582825,
#   'pending': 11808,
#   'hospitalizedCurrently': 40199,
#   'hospitalizedCumulative': 776361,
#   'inIcuCurrently': 8134,
#   'inIcuCumulative': 45475,
#   'onVentilatorCurrently': 2802,
#   'onVentilatorCumulative': 4281,
#   'dateChecked': '2021-03-07T24:00:00Z',
#   'death': 515151,
#   'hospitalized': 776361,
#   'totalTestResults': 363825123,
#   'lastModified': '2021-03-07T24:00:00Z',
#   'recovered': None,
#   'total': 0,
#   'posNeg': 0,
#   'deathIncrease': 842,
#   'hospitalizedIncrease': 726,
#   'negativeIncrease': 131835,
#   'positiveIncrease': 41835,
#   'totalTestResultsIncrease': 1170059,
#   'hash': 'a80d0063822e251249fd9a44730c49cb23defd83'}]
