# %%
from covid import *
from vaccine_import import *
# %matplotlib inline
# Out:
# Start importing World-data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/
# Start importing USA-data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/
# Start importing single data  ./data/COVID-19/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv
# Start importing single data vaccine in US ./data/Vaccine/COVID-19/data_tables/vaccine_data/us_data/time_series/vaccine_data_us_timeline.csv
# Start importing single data vaccine in the World ./data/Vaccine/COVID-19/data_tables/vaccine_data/global_data/vaccine_data_global.csv
# Start importing time series data vaccine in the World ./data/Vaccine/COVID-19/data_tables/vaccine_data/global_data/time_series_covid19_vaccine_global.csv

# %%
# TODO: check correlation between population, nr.of vaccines, confirmed cases, death cases

# %%
total_confirmed_vaccine_us
# Out:
#       Province_State        Date Vaccine_Type  FIPS Country_Region      Lat  \
# 0            Alabama  2020-12-10          All   1.0             US  32.3182
# 1            Alabama  2020-12-10      Moderna   1.0             US  32.3182
# 2            Alabama  2020-12-10       Pfizer   1.0             US  32.3182
# 3            Alabama  2020-12-11          All   1.0             US  32.3182
# 4            Alabama  2020-12-11      Moderna   1.0             US  32.3182
# ...              ...         ...          ...   ...            ...      ...
# 72323        Wyoming  2021-07-29      Janssen  56.0             US  42.7560
# 72324        Wyoming  2021-07-29       Pfizer  56.0             US  42.7560
# 72325        Wyoming  2021-07-29      Moderna  56.0             US  42.7560
# 72326        Wyoming  2021-07-29          All  56.0             US  42.7560
# 72327        Wyoming  2021-07-29   Unassigned  56.0             US  42.7560
#
#           Long_  Doses_alloc  Doses_shipped  Doses_admin  Stage_One_Doses  \
# 0      -86.9023          NaN            NaN          NaN              NaN
# 1      -86.9023          NaN            NaN          NaN              NaN
# 2      -86.9023          NaN            NaN          NaN              NaN
# 3      -86.9023          NaN            NaN          NaN              NaN
# 4      -86.9023          NaN            NaN          NaN              NaN
# ...         ...          ...            ...          ...              ...
# 72323 -107.3025          NaN        34000.0      18896.0          17788.0
# 72324 -107.3025          NaN       237855.0     217605.0              NaN
# 72325 -107.3025          NaN       255040.0     209072.0              NaN
# 72326 -107.3025          NaN       526895.0     445810.0         240393.0
# 72327 -107.3025          NaN            0.0          0.0         222605.0
#
#        Stage_Two_Doses Combined_Key
# 0                  NaN  Alabama, US
# 1                  NaN  Alabama, US
# 2                  NaN  Alabama, US
# 3                  NaN  Alabama, US
# 4                  NaN  Alabama, US
# ...                ...          ...
# 72323              NaN  Wyoming, US
# 72324          99634.0  Wyoming, US
# 72325          94126.0  Wyoming, US
# 72326         193821.0  Wyoming, US
# 72327             61.0  Wyoming, US
#
# [72328 rows x 13 columns]

# %%
rcParams['figure.figsize'] = 20, 6
total_confirmed_vaccine_global['Date'].max()
# Out:
# '2021-07-30'

# %%
total_confirmed_vaccine_us
# Out:
#       Province_State        Date Vaccine_Type  FIPS Country_Region      Lat  \
# 0            Alabama  2020-12-10          All   1.0             US  32.3182
# 1            Alabama  2020-12-10      Moderna   1.0             US  32.3182
# 2            Alabama  2020-12-10       Pfizer   1.0             US  32.3182
# 3            Alabama  2020-12-11          All   1.0             US  32.3182
# 4            Alabama  2020-12-11      Moderna   1.0             US  32.3182
# ...              ...         ...          ...   ...            ...      ...
# 72323        Wyoming  2021-07-29      Janssen  56.0             US  42.7560
# 72324        Wyoming  2021-07-29       Pfizer  56.0             US  42.7560
# 72325        Wyoming  2021-07-29      Moderna  56.0             US  42.7560
# 72326        Wyoming  2021-07-29          All  56.0             US  42.7560
# 72327        Wyoming  2021-07-29   Unassigned  56.0             US  42.7560
#
#           Long_  Doses_alloc  Doses_shipped  Doses_admin  Stage_One_Doses  \
# 0      -86.9023          NaN            NaN          NaN              NaN
# 1      -86.9023          NaN            NaN          NaN              NaN
# 2      -86.9023          NaN            NaN          NaN              NaN
# 3      -86.9023          NaN            NaN          NaN              NaN
# 4      -86.9023          NaN            NaN          NaN              NaN
# ...         ...          ...            ...          ...              ...
# 72323 -107.3025          NaN        34000.0      18896.0          17788.0
# 72324 -107.3025          NaN       237855.0     217605.0              NaN
# 72325 -107.3025          NaN       255040.0     209072.0              NaN
# 72326 -107.3025          NaN       526895.0     445810.0         240393.0
# 72327 -107.3025          NaN            0.0          0.0         222605.0
#
#        Stage_Two_Doses Combined_Key
# 0                  NaN  Alabama, US
# 1                  NaN  Alabama, US
# 2                  NaN  Alabama, US
# 3                  NaN  Alabama, US
# 4                  NaN  Alabama, US
# ...                ...          ...
# 72323              NaN  Wyoming, US
# 72324          99634.0  Wyoming, US
# 72325          94126.0  Wyoming, US
# 72326         193821.0  Wyoming, US
# 72327             61.0  Wyoming, US
#
# [72328 rows x 13 columns]

# %%
total_confirmed_vaccine_us['Date'].tolist()[-1]
# Out:
# '2021-07-29'

# %% [markdown]
# ### Update Data in the WORLD changed from 12.04.2020

# %%
print("Latest Update on the total vaccines already delivered\n")
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region']=='World']
# Out:
# Latest Update on the total vaccines already delivered
#     Province_State Country_Region        Date  Doses_admin  \
# 491            NaN          World  2021-07-30   4004798419
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 491                 2.132912e+09             1.088865e+09         2021/07/30
#
#      UID
# 491  NaN

# %%
# total_confirmed_vaccine_global.drop(total_confirmed_vaccine_global.tail(1).index,inplace=True) 
total_confirmed_vaccine_global
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 0              NaN    Afghanistan  2021-07-30      1381416
# 1              NaN        Albania  2021-07-30      1138771
# 2              NaN        Algeria  2021-07-30        75000
# 3              NaN        Andorra  2021-07-30        82349
# 4              NaN         Angola  2021-07-30      1592537
# ..             ...            ...         ...          ...
# 489            NaN      Venezuela  2021-07-30      4000000
# 490            NaN        Vietnam  2021-07-30      5321839
# 491            NaN          World  2021-07-30   4004798419
# 492            NaN         Zambia  2021-07-30       400639
# 493            NaN       Zimbabwe  2021-07-30      2178709
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 0                   9.398350e+05             2.191590e+05         2021/07/30
# 1                   6.400470e+05             4.987240e+05         2021/07/30
# 2                   7.500000e+04             0.000000e+00         2021/07/30
# 3                   4.844500e+04             3.390400e+04         2021/07/30
# 4                   9.583730e+05             6.341640e+05         2021/07/30
# ..                           ...                      ...                ...
# 489                 2.900000e+06             1.100000e+06         2021/07/30
# 490                 4.825209e+06             4.966300e+05         2021/07/30
# 491                 2.132912e+09             1.088865e+09         2021/07/30
# 492                 2.825560e+05             1.180830e+05         2021/07/30
# 493                 1.491493e+06             6.872160e+05         2021/07/30
#
#        UID
# 0      4.0
# 1      8.0
# 2     12.0
# 3     20.0
# 4     24.0
# ..     ...
# 489  862.0
# 490  704.0
# 491    NaN
# 492  894.0
# 493  716.0
#
# [494 rows x 8 columns]

# %%
total_confirmed_vaccine_global[['Country_Region', 'Doses_admin']]
# Out:
#     Country_Region  Doses_admin
# 0      Afghanistan      1381416
# 1          Albania      1138771
# 2          Algeria        75000
# 3          Andorra        82349
# 4           Angola      1592537
# ..             ...          ...
# 489      Venezuela      4000000
# 490        Vietnam      5321839
# 491          World   4004798419
# 492         Zambia       400639
# 493       Zimbabwe      2178709
#
# [494 rows x 2 columns]

# %%
total_confirmed_vaccine_global
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 0              NaN    Afghanistan  2021-07-30      1381416
# 1              NaN        Albania  2021-07-30      1138771
# 2              NaN        Algeria  2021-07-30        75000
# 3              NaN        Andorra  2021-07-30        82349
# 4              NaN         Angola  2021-07-30      1592537
# ..             ...            ...         ...          ...
# 489            NaN      Venezuela  2021-07-30      4000000
# 490            NaN        Vietnam  2021-07-30      5321839
# 491            NaN          World  2021-07-30   4004798419
# 492            NaN         Zambia  2021-07-30       400639
# 493            NaN       Zimbabwe  2021-07-30      2178709
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 0                   9.398350e+05             2.191590e+05         2021/07/30
# 1                   6.400470e+05             4.987240e+05         2021/07/30
# 2                   7.500000e+04             0.000000e+00         2021/07/30
# 3                   4.844500e+04             3.390400e+04         2021/07/30
# 4                   9.583730e+05             6.341640e+05         2021/07/30
# ..                           ...                      ...                ...
# 489                 2.900000e+06             1.100000e+06         2021/07/30
# 490                 4.825209e+06             4.966300e+05         2021/07/30
# 491                 2.132912e+09             1.088865e+09         2021/07/30
# 492                 2.825560e+05             1.180830e+05         2021/07/30
# 493                 1.491493e+06             6.872160e+05         2021/07/30
#
#        UID
# 0      4.0
# 1      8.0
# 2     12.0
# 3     20.0
# 4     24.0
# ..     ...
# 489  862.0
# 490  704.0
# 491    NaN
# 492  894.0
# 493  716.0
#
# [494 rows x 8 columns]

# %%
for country in country_pop_dict.keys(): 
    total_confirmed_vaccine_global.loc[total_confirmed_vaccine_global['Country_Region']==country, 'Population'] = country_pop_dict[country]

total_confirmed_vaccine_global.loc[total_confirmed_vaccine_global['Country_Region']=='World', 'Population'] = 7674000000
total_confirmed_vaccine_global.loc[total_confirmed_vaccine_global['Country_Region']=='US (Aggregate)', 'Population'] = country_pop_dict['US']

total_confirmed_vaccine_global['ratio_vaccine_population'] = total_confirmed_vaccine_global['Doses_admin'] / total_confirmed_vaccine_global['Population']

# %%
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region'] == 'Switzerland']
# Out:
# Empty DataFrame
# Columns: [Province_State, Country_Region, Date, Doses_admin, People_partially_vaccinated, People_fully_vaccinated, Report_Date_String, UID, Population, ratio_vaccine_population]
# Index: []

# %%
total_confirmed_vaccine_global
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 0              NaN    Afghanistan  2021-07-30      1381416
# 1              NaN        Albania  2021-07-30      1138771
# 2              NaN        Algeria  2021-07-30        75000
# 3              NaN        Andorra  2021-07-30        82349
# 4              NaN         Angola  2021-07-30      1592537
# ..             ...            ...         ...          ...
# 489            NaN      Venezuela  2021-07-30      4000000
# 490            NaN        Vietnam  2021-07-30      5321839
# 491            NaN          World  2021-07-30   4004798419
# 492            NaN         Zambia  2021-07-30       400639
# 493            NaN       Zimbabwe  2021-07-30      2178709
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 0                   9.398350e+05             2.191590e+05         2021/07/30
# 1                   6.400470e+05             4.987240e+05         2021/07/30
# 2                   7.500000e+04             0.000000e+00         2021/07/30
# 3                   4.844500e+04             3.390400e+04         2021/07/30
# 4                   9.583730e+05             6.341640e+05         2021/07/30
# ..                           ...                      ...                ...
# 489                 2.900000e+06             1.100000e+06         2021/07/30
# 490                 4.825209e+06             4.966300e+05         2021/07/30
# 491                 2.132912e+09             1.088865e+09         2021/07/30
# 492                 2.825560e+05             1.180830e+05         2021/07/30
# 493                 1.491493e+06             6.872160e+05         2021/07/30
#
#        UID   Population ratio_vaccine_population
# 0      4.0  3.89283e+07                0.0354861
# 1      8.0   2.8778e+06                 0.395709
# 2     12.0   4.3851e+07               0.00171034
# 3     20.0        77265                   1.0658
# 4     24.0  3.28663e+07                0.0484551
# ..     ...          ...                      ...
# 489  862.0  2.84359e+07                 0.140667
# 490  704.0  9.73386e+07                0.0546735
# 491    NaN   7674000000                 0.521866
# 492  894.0   1.8384e+07                0.0217929
# 493  716.0  1.48629e+07                 0.146587
#
# [494 rows x 10 columns]

# %%
total_confirmed_vaccine_global.sort_values(by='ratio_vaccine_population', ascending=False)[['Country_Region', 'ratio_vaccine_population']].groupby(by='Country_Region').max()
# Out:
#                 ratio_vaccine_population
# Country_Region
# Afghanistan                     0.035486
# Albania                         0.395709
# Algeria                         0.001710
# Andorra                         1.065800
# Angola                          0.048455
# ...                                  ...
# Venezuela                       0.140667
# Vietnam                         0.054673
# World                           0.521866
# Zambia                          0.021793
# Zimbabwe                        0.146587
#
# [164 rows x 1 columns]

# %%
total_confirmed_vaccine_global[['Country_Region', 'ratio_vaccine_population']].groupby(by='Country_Region').max().sort_values(by='ratio_vaccine_population', ascending=False).head(30)
# Out:
#                       ratio_vaccine_population
# Country_Region
# Malta                                 1.702106
# United Arab Emirates                  1.686157
# Palau                                 1.452021
# Seychelles                            1.438225
# Iceland                               1.372648
# Uruguay                               1.371122
# Bahrain                               1.344417
# San Marino                            1.331958
# Chile                                 1.325440
# Qatar                                 1.302396
# Israel                                1.287197
# Canada                                1.272631
# Mongolia                              1.258982
# United Kingdom                        1.252354
# Bhutan                                1.248882
# Singapore                             1.248696
# Denmark                               1.246518
# Belgium                               1.220263
# Netherlands                           1.182087
# Spain                                 1.180315
# Portugal                              1.162355
# Ireland                               1.159672
# China                                 1.139942
# Italy                                 1.117149
# Luxembourg                            1.115568
# France                                1.104809
# Germany                               1.092945
# Maldives                              1.078610
# Hungary                               1.073069
# Austria                               1.065958

# %%
total_confirmed_vaccine_global[['Country_Region', 'ratio_vaccine_population']].groupby(by='Country_Region').max().sort_values(by='ratio_vaccine_population', ascending=False).tail(30)
# Out:
#                   ratio_vaccine_population
# Country_Region
# Eswatini                          0.057365
# Togo                              0.054864
# Vietnam                           0.054673
# Senegal                           0.054142
# Egypt                             0.052157
# Armenia                           0.051854
# Rwanda                            0.049946
# Angola                            0.048455
# Mauritania                        0.041314
# Ghana                             0.040916
# Gabon                             0.039170
# Cote d'Ivoire                     0.035766
# Afghanistan                       0.035486
# Kenya                             0.031759
# Sierra Leone                      0.028254
# Iraq                              0.027046
# Malawi                            0.025739
# Uganda                            0.024814
# Mozambique                        0.022109
# Zambia                            0.021793
# Ethiopia                          0.019117
# Nigeria                           0.019108
# Sudan                             0.018485
# Gambia                            0.018024
# Cameroon                          0.012502
# Papua New Guinea                  0.009874
# Mali                              0.009721
# Syria                             0.007498
# South Sudan                       0.005091
# Algeria                           0.001710

# %%
countries_confirmed_by_day.iloc[-1]
# Out:
# Colombia            9690.0
# Korea, South        1707.0
# Jordan              1008.0
# Faroe Islands          0.0
# South Sudan            0.0
#                      ...
# Panama              1022.0
# Madagascar            30.0
# Malawi               760.0
# Palau                  0.0
# Others_and_ships       0.0
# Name: 554, Length: 229, dtype: float64

# %%
country = ['Luxembourg', 'Vietnam', 'Germany']
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region'].isin(country)]
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 188            NaN        Germany  2021-07-30     91571257
# 323            NaN     Luxembourg  2021-07-30       698319
# 490            NaN        Vietnam  2021-07-30      5321839
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 188                   51007130.0               42362788.0         2021/07/30
# 323                     392073.0                 299217.0         2021/07/30
# 490                    4825209.0                 496630.0         2021/07/30
#
#        UID   Population ratio_vaccine_population
# 188  276.0  8.37839e+07                  1.09295
# 323  442.0       625976                  1.11557
# 490  704.0  9.73386e+07                0.0546735

# %%
total_confirmed_vaccine_global.sort_values(by='Doses_admin', ascending=False).head(15).plot(x='Country_Region', y='Doses_admin', kind='bar')
plt.xticks(rotation=45)
total_confirmed_vaccine_global.sort_values(by='Doses_admin', ascending=False).head(15)
# Out:
#     Province_State  Country_Region        Date  Doses_admin  \
# 491            NaN           World  2021-07-30   4004798419
# 112            NaN           China  2021-07-30   1601249000
# 198            NaN           India  2021-07-30    456033754
# 444            NaN              US  2021-07-30    344071595
# 445            NaN  US (Aggregate)  2021-07-30    343060727
# 64             NaN          Brazil  2021-07-30    132054426
# 188            NaN         Germany  2021-07-30     91571257
# 474            NaN  United Kingdom  2021-07-30     85017321
# 299            NaN           Japan  2021-07-30     84009438
# 184            NaN          France  2021-07-30     72114795
# 443            NaN          Turkey  2021-07-30     71707786
# 478        England  United Kingdom  2021-07-30     70632301
# 276            NaN           Italy  2021-07-30     67544883
# 236            NaN       Indonesia  2021-07-30     66952414
# 349            NaN          Mexico  2021-07-30     63313209
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 491                 2.132912e+09             1.088865e+09         2021/07/30
# 112                 6.220000e+08             2.232990e+08         2021/07/30
# 198                 3.525453e+08             9.816099e+07         2021/07/30
# 444                 1.899459e+08             1.638689e+08         2021/07/30
# 445                 1.899459e+08             1.638689e+08         2021/07/30
# 64                  1.022948e+08             3.952483e+07         2021/07/30
# 188                 5.100713e+07             4.236279e+07         2021/07/30
# 474                 4.668924e+07             3.761091e+07         2021/07/30
# 299                 4.827023e+07             3.432324e+07         2021/07/30
# 184                 3.990173e+07             3.057827e+07         2021/07/30
# 443                 4.033096e+07             2.556617e+07         2021/07/30
# 478                          NaN                      NaN         2021/07/30
# 276                 3.786441e+07             3.047631e+07         2021/07/30
# 236                 4.573491e+07             1.910316e+07         2021/07/30
# 349                 4.418894e+07             2.485617e+07         2021/07/30
#
#          UID   Population ratio_vaccine_population
# 491      NaN   7674000000                 0.521866
# 112    156.0  1.40468e+09                  1.13994
# 198    356.0     1.38e+09                 0.330458
# 444    840.0  3.29466e+08                  1.04433
# 445    840.0  3.29466e+08                  1.04126
# 64      76.0  2.12559e+08                 0.621259
# 188    276.0  8.37839e+07                  1.09295
# 474    826.0   6.7886e+07                  1.25235
# 299    392.0  1.26476e+08                  0.66423
# 184    250.0  6.52735e+07                  1.10481
# 443    792.0  8.43391e+07                 0.850232
# 478  82601.0   6.7886e+07                  1.04045
# 276    380.0  6.04618e+07                  1.11715
# 236    360.0  2.73524e+08                 0.244777
# 349    484.0  1.27792e+08                 0.495438

# %%
countries = ['China', 'Germany', 'Italy', 'Japan', 'Australia', 'Luxembourg', 'US', 'United Kingdom', 'Canada', 'Vietnam', 'Philippines', 'Israel']

total_countries_vaccinated = total_confirmed_vaccine_global.groupby(by='Country_Region').sum()

# total_countries_vaccinated['vaccination_rate'] = total_countries_vaccinated['People_partially_vaccinated']/total_countries_vaccinated['Doses_admin']*100
total_countries_vaccinated['vaccination_speed']=total_countries_vaccinated.apply(lambda row: row.People_partially_vaccinated/row.Doses_admin*100, axis=1)
total_countries_vaccinated.sort_values(by='vaccination_speed', ascending=False)['vaccination_speed'].head(20).plot(kind='bar', title='Countries with high Vaccination Speed', color='lightgreen')
plt.xticks(rotation=45)
total_countries_vaccinated.sort_values(by='vaccination_speed', ascending=False).head(20)
# Out:
#                   Doses_admin  People_partially_vaccinated  \
# Country_Region
# Ethiopia              2197813                    2197813.0
# Algeria                 75000                      75000.0
# Uganda                1135036                    1135036.0
# Cote d'Ivoire          943437                     943437.0
# Taiwan*               7588692                    7273091.0
# Syria                  131221                     121909.0
# Mauritania             192094                     177259.0
# South Sudan             56989                      52226.0
# Vietnam               5321839                    4825209.0
# Papua New Guinea        88343                      78399.0
# Honduras              1705994                    1511974.0
# Paraguay              2123997                    1837008.0
# Cameroon               331875                     279987.0
# Brunei                 150102                     126050.0
# Oman                  1887421                    1550910.0
# South Africa          6854667                    5580927.0
# Sri Lanka            10119124                    8232194.0
# Guatemala             1950167                    1561791.0
# Fiji                   553676                     441171.0
# Malawi                 492390                     390738.0
#
#                   People_fully_vaccinated    UID  vaccination_speed
# Country_Region
# Ethiopia                              0.0  231.0         100.000000
# Algeria                               0.0   12.0         100.000000
# Uganda                             4129.0  800.0         100.000000
# Cote d'Ivoire                         0.0  384.0         100.000000
# Taiwan*                          315601.0  158.0          95.841167
# Syria                              9312.0  760.0          92.903575
# Mauritania                        14835.0  478.0          92.277218
# South Sudan                        4763.0  728.0          91.642247
# Vietnam                          496630.0  704.0          90.668075
# Papua New Guinea                   9944.0  598.0          88.743873
# Honduras                         194020.0  340.0          88.627158
# Paraguay                         286989.0  600.0          86.488258
# Cameroon                          51888.0  120.0          84.365198
# Brunei                            24052.0   96.0          83.976229
# Oman                             336511.0  512.0          82.170856
# South Africa                    2580001.0  710.0          81.417916
# Sri Lanka                       1886930.0  144.0          81.352833
# Guatemala                        315459.0  320.0          80.084988
# Fiji                              97268.0  242.0          79.680355
# Malawi                            57670.0  454.0          79.355389

# %%
total_countries_vaccinated.sort_values(by='vaccination_speed', ascending=False)['vaccination_speed'].tail(20).plot(kind='bar', title='Countries with slow Vaccination Speed ', color='lightgreen')
plt.xticks(rotation=45)
total_countries_vaccinated.sort_values(by='vaccination_speed', ascending=False).tail(20)
# Out:
#                   Doses_admin  People_partially_vaccinated  \
# Country_Region
# Sierra Leone           225380                      82145.0
# Indonesia           133904828                   45734912.0
# Nepal                10399072                    3544043.0
# Australia            24011956                    8048704.0
# Malaysia             39004904                   12841212.0
# Pakistan             28743225                    9308890.0
# Colombia             52373428                   16455361.0
# Bangladesh           21131228                    6622525.0
# Ukraine              10752248                    3350500.0
# Italy               135089766                   37864407.0
# Canada               96352678                   26878305.0
# United Kingdom      169731625                   46689242.0
# Czechia              20504054                    5586127.0
# Lithuania             5106588                    1385066.0
# Poland               68193096                   18192439.0
# Slovenia              3438698                     909574.0
# Palau                   26148                          0.0
# Marshall Islands        35902                          0.0
# Micronesia              55633                          0.0
# Korea, South         25791209                          0.0
#
#                   People_fully_vaccinated         UID  vaccination_speed
# Country_Region
# Sierra Leone                      15170.0       694.0          36.447333
# Indonesia                      19103162.0  12600990.0          34.154789
# Nepal                           1503312.0   3668552.0          34.080378
# Australia                       3545062.0     32481.0          33.519568
# Malaysia                        6104836.0    779211.0          32.922045
# Pakistan                        5478872.0       586.0          32.386380
# Colombia                       11457631.0    578765.0          31.419293
# Bangladesh                      4298351.0     45095.0          31.339991
# Ukraine                         1874958.0   2011158.0          31.160926
# Italy                          30476306.0    798669.0          28.029071
# Canada                         21651918.0    161418.0          27.895753
# United Kingdom                 37610911.0    334609.0          27.507686
# Czechia                         4735650.0    304823.0          27.244012
# Lithuania                       1227225.0    484506.0          27.123120
# Poland                         17225194.0   1047969.0          26.677831
# Slovenia                         798602.0    917296.0          26.451116
# Palau                                 0.0       585.0           0.000000
# Marshall Islands                      0.0       584.0           0.000000
# Micronesia                            0.0       583.0           0.000000
# Korea, South                          0.0       410.0           0.000000

# %%
total_confirmed_vaccine_global.sort_values(by='People_partially_vaccinated', ascending=False).head(20).plot(x='Country_Region', y='People_partially_vaccinated', kind='bar')
plt.xticks(rotation=45)
total_confirmed_vaccine_global.sort_values(by='People_partially_vaccinated', ascending=False).head(20)
# Out:
#     Province_State  Country_Region        Date  Doses_admin  \
# 491            NaN           World  2021-07-30   4004798419
# 112            NaN           China  2021-07-30   1601249000
# 198            NaN           India  2021-07-30    456033754
# 444            NaN              US  2021-07-30    344071595
# 445            NaN  US (Aggregate)  2021-07-30    343060727
# 64             NaN          Brazil  2021-07-30    132054426
# 188            NaN         Germany  2021-07-30     91571257
# 299            NaN           Japan  2021-07-30     84009438
# 474            NaN  United Kingdom  2021-07-30     85017321
# 236            NaN       Indonesia  2021-07-30     66952414
# 349            NaN          Mexico  2021-07-30     63313209
# 443            NaN          Turkey  2021-07-30     71707786
# 184            NaN          France  2021-07-30     72114795
# 276            NaN           Italy  2021-07-30     67544883
# 401            NaN          Russia  2021-07-30     60481422
# 432            NaN           Spain  2021-07-30     55185352
# 97             NaN          Canada  2021-07-30     48176339
# 6              NaN       Argentina  2021-07-30     30655272
# 408            NaN    Saudi Arabia  2021-07-30     26317134
# 380            NaN          Poland  2021-07-30     34096548
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 491                 2.132912e+09             1.088865e+09         2021/07/30
# 112                 6.220000e+08             2.232990e+08         2021/07/30
# 198                 3.525453e+08             9.816099e+07         2021/07/30
# 444                 1.899459e+08             1.638689e+08         2021/07/30
# 445                 1.899459e+08             1.638689e+08         2021/07/30
# 64                  1.022948e+08             3.952483e+07         2021/07/30
# 188                 5.100713e+07             4.236279e+07         2021/07/30
# 299                 4.827023e+07             3.432324e+07         2021/07/30
# 474                 4.668924e+07             3.761091e+07         2021/07/30
# 236                 4.573491e+07             1.910316e+07         2021/07/30
# 349                 4.418894e+07             2.485617e+07         2021/07/30
# 443                 4.033096e+07             2.556617e+07         2021/07/30
# 184                 3.990173e+07             3.057827e+07         2021/07/30
# 276                 3.786441e+07             3.047631e+07         2021/07/30
# 401                 3.556556e+07             2.365665e+07         2021/07/30
# 432                 3.131514e+07             2.642010e+07         2021/07/30
# 97                  2.687830e+07             2.165192e+07         2021/07/30
# 6                   2.430243e+07             6.352840e+06         2021/07/30
# 408                 1.845146e+07             7.421540e+06         2021/07/30
# 380                 1.819244e+07             1.722519e+07         2021/07/30
#
#        UID   Population ratio_vaccine_population
# 491    NaN   7674000000                 0.521866
# 112  156.0  1.40468e+09                  1.13994
# 198  356.0     1.38e+09                 0.330458
# 444  840.0  3.29466e+08                  1.04433
# 445  840.0  3.29466e+08                  1.04126
# 64    76.0  2.12559e+08                 0.621259
# 188  276.0  8.37839e+07                  1.09295
# 299  392.0  1.26476e+08                  0.66423
# 474  826.0   6.7886e+07                  1.25235
# 236  360.0  2.73524e+08                 0.244777
# 349  484.0  1.27792e+08                 0.495438
# 443  792.0  8.43391e+07                 0.850232
# 184  250.0  6.52735e+07                  1.10481
# 276  380.0  6.04618e+07                  1.11715
# 401  643.0  1.45934e+08                 0.414442
# 432  724.0  4.67548e+07                  1.18031
# 97   124.0  3.78557e+07                  1.27263
# 6     32.0  4.51958e+07                 0.678277
# 408  682.0  3.48139e+07                 0.755938
# 380  616.0  3.78466e+07                 0.900914

# %%
total_confirmed_vaccine_global.sort_values(by='People_fully_vaccinated', ascending=False).head(20).plot(x='Country_Region', y='People_fully_vaccinated', kind='bar')
plt.xticks(rotation=45)
total_confirmed_vaccine_global.sort_values(by='People_fully_vaccinated', ascending=False).head(20)
# Out:
#     Province_State  Country_Region        Date  Doses_admin  \
# 491            NaN           World  2021-07-30   4004798419
# 112            NaN           China  2021-07-30   1601249000
# 444            NaN              US  2021-07-30    344071595
# 445            NaN  US (Aggregate)  2021-07-30    343060727
# 198            NaN           India  2021-07-30    456033754
# 188            NaN         Germany  2021-07-30     91571257
# 64             NaN          Brazil  2021-07-30    132054426
# 474            NaN  United Kingdom  2021-07-30     85017321
# 299            NaN           Japan  2021-07-30     84009438
# 184            NaN          France  2021-07-30     72114795
# 276            NaN           Italy  2021-07-30     67544883
# 432            NaN           Spain  2021-07-30     55185352
# 443            NaN          Turkey  2021-07-30     71707786
# 349            NaN          Mexico  2021-07-30     63313209
# 401            NaN          Russia  2021-07-30     60481422
# 97             NaN          Canada  2021-07-30     48176339
# 236            NaN       Indonesia  2021-07-30     66952414
# 380            NaN          Poland  2021-07-30     34096548
# 111            NaN           Chile  2021-07-30     25337393
# 115            NaN        Colombia  2021-07-30     26186714
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 491                 2.132912e+09             1.088865e+09         2021/07/30
# 112                 6.220000e+08             2.232990e+08         2021/07/30
# 444                 1.899459e+08             1.638689e+08         2021/07/30
# 445                 1.899459e+08             1.638689e+08         2021/07/30
# 198                 3.525453e+08             9.816099e+07         2021/07/30
# 188                 5.100713e+07             4.236279e+07         2021/07/30
# 64                  1.022948e+08             3.952483e+07         2021/07/30
# 474                 4.668924e+07             3.761091e+07         2021/07/30
# 299                 4.827023e+07             3.432324e+07         2021/07/30
# 184                 3.990173e+07             3.057827e+07         2021/07/30
# 276                 3.786441e+07             3.047631e+07         2021/07/30
# 432                 3.131514e+07             2.642010e+07         2021/07/30
# 443                 4.033096e+07             2.556617e+07         2021/07/30
# 349                 4.418894e+07             2.485617e+07         2021/07/30
# 401                 3.556556e+07             2.365665e+07         2021/07/30
# 97                  2.687830e+07             2.165192e+07         2021/07/30
# 236                 4.573491e+07             1.910316e+07         2021/07/30
# 380                 1.819244e+07             1.722519e+07         2021/07/30
# 111                 1.377223e+07             1.206819e+07         2021/07/30
# 115                 1.645536e+07             1.145763e+07         2021/07/30
#
#        UID   Population ratio_vaccine_population
# 491    NaN   7674000000                 0.521866
# 112  156.0  1.40468e+09                  1.13994
# 444  840.0  3.29466e+08                  1.04433
# 445  840.0  3.29466e+08                  1.04126
# 198  356.0     1.38e+09                 0.330458
# 188  276.0  8.37839e+07                  1.09295
# 64    76.0  2.12559e+08                 0.621259
# 474  826.0   6.7886e+07                  1.25235
# 299  392.0  1.26476e+08                  0.66423
# 184  250.0  6.52735e+07                  1.10481
# 276  380.0  6.04618e+07                  1.11715
# 432  724.0  4.67548e+07                  1.18031
# 443  792.0  8.43391e+07                 0.850232
# 349  484.0  1.27792e+08                 0.495438
# 401  643.0  1.45934e+08                 0.414442
# 97   124.0  3.78557e+07                  1.27263
# 236  360.0  2.73524e+08                 0.244777
# 380  616.0  3.78466e+07                 0.900914
# 111  152.0  1.91162e+07                  1.32544
# 115  170.0  5.08829e+07                 0.514647

# %%
# TODO: check correlation between total vaccines vs population, total vaccines vs confirmed cases, total vaccines vs death cases
