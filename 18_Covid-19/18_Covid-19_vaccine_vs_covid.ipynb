# %%
from covid import *
from vaccine_import import *
# %matplotlib inline
# Out:
# Start importing World-data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/
# Start importing USA-data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/
# Start importing single data  ./data/COVID-19/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv
# Start importing single data vaccine in US ./data/Vaccine/COVID-19/data_tables/vaccine_data/us_data/time_series/vaccine_data_us_timeline.csv
# Start importing single data vaccine in the World ./data/Vaccine/COVID-19/data_tables/vaccine_data/global_data/vaccine_data_global.csv
# Start importing time series data vaccine in the World ./data/Vaccine/COVID-19/data_tables/vaccine_data/global_data/time_series_covid19_vaccine_global.csv

# %%
total_confirmed_vaccine_us
# Out:
#        Province_State        Date Vaccine_Type  FIPS Country_Region      Lat  \
# 0             Alabama  2020-12-10          All   1.0             US  32.3182
# 1             Alabama  2020-12-10      Moderna   1.0             US  32.3182
# 2             Alabama  2020-12-10       Pfizer   1.0             US  32.3182
# 3             Alabama  2020-12-11          All   1.0             US  32.3182
# 4             Alabama  2020-12-11      Moderna   1.0             US  32.3182
# ...               ...         ...          ...   ...            ...      ...
# 103799        Wyoming  2021-10-23      Janssen  56.0             US  42.7560
# 103800        Wyoming  2021-10-23       Pfizer  56.0             US  42.7560
# 103801        Wyoming  2021-10-23      Moderna  56.0             US  42.7560
# 103802        Wyoming  2021-10-23          All  56.0             US  42.7560
# 103803        Wyoming  2021-10-23   Unassigned  56.0             US  42.7560
#
#            Long_  Doses_alloc  Doses_shipped  Doses_admin  Stage_One_Doses  \
# 0       -86.9023          NaN            NaN          NaN              NaN
# 1       -86.9023          NaN            NaN          NaN              NaN
# 2       -86.9023          NaN            NaN          NaN              NaN
# 3       -86.9023          NaN            NaN          NaN              NaN
# 4       -86.9023          NaN            NaN          NaN              NaN
# ...          ...          ...            ...          ...              ...
# 103799 -107.3025          NaN        38800.0      24394.0          22867.0
# 103800 -107.3025          NaN       352785.0     291397.0              NaN
# 103801 -107.3025          NaN       324740.0     241037.0              NaN
# 103802 -107.3025          NaN       716325.0     557340.0         291149.0
# 103803 -107.3025          NaN            0.0          0.0         268282.0
#
#         Stage_Two_Doses Combined_Key
# 0                   NaN  Alabama, US
# 1                   NaN  Alabama, US
# 2                   NaN  Alabama, US
# 3                   NaN  Alabama, US
# 4                   NaN  Alabama, US
# ...                 ...          ...
# 103799              NaN  Wyoming, US
# 103800         122567.0  Wyoming, US
# 103801         106141.0  Wyoming, US
# 103802         228910.0  Wyoming, US
# 103803            202.0  Wyoming, US
#
# [103804 rows x 13 columns]

# %%
rcParams['figure.figsize'] = 20, 6
total_confirmed_vaccine_global['Date'].max()
# Out:
# '2021-10-24'

# %%
total_confirmed_vaccine_us
# Out:
#        Province_State        Date Vaccine_Type  FIPS Country_Region      Lat  \
# 0             Alabama  2020-12-10          All   1.0             US  32.3182
# 1             Alabama  2020-12-10      Moderna   1.0             US  32.3182
# 2             Alabama  2020-12-10       Pfizer   1.0             US  32.3182
# 3             Alabama  2020-12-11          All   1.0             US  32.3182
# 4             Alabama  2020-12-11      Moderna   1.0             US  32.3182
# ...               ...         ...          ...   ...            ...      ...
# 103799        Wyoming  2021-10-23      Janssen  56.0             US  42.7560
# 103800        Wyoming  2021-10-23       Pfizer  56.0             US  42.7560
# 103801        Wyoming  2021-10-23      Moderna  56.0             US  42.7560
# 103802        Wyoming  2021-10-23          All  56.0             US  42.7560
# 103803        Wyoming  2021-10-23   Unassigned  56.0             US  42.7560
#
#            Long_  Doses_alloc  Doses_shipped  Doses_admin  Stage_One_Doses  \
# 0       -86.9023          NaN            NaN          NaN              NaN
# 1       -86.9023          NaN            NaN          NaN              NaN
# 2       -86.9023          NaN            NaN          NaN              NaN
# 3       -86.9023          NaN            NaN          NaN              NaN
# 4       -86.9023          NaN            NaN          NaN              NaN
# ...          ...          ...            ...          ...              ...
# 103799 -107.3025          NaN        38800.0      24394.0          22867.0
# 103800 -107.3025          NaN       352785.0     291397.0              NaN
# 103801 -107.3025          NaN       324740.0     241037.0              NaN
# 103802 -107.3025          NaN       716325.0     557340.0         291149.0
# 103803 -107.3025          NaN            0.0          0.0         268282.0
#
#         Stage_Two_Doses Combined_Key
# 0                   NaN  Alabama, US
# 1                   NaN  Alabama, US
# 2                   NaN  Alabama, US
# 3                   NaN  Alabama, US
# 4                   NaN  Alabama, US
# ...                 ...          ...
# 103799              NaN  Wyoming, US
# 103800         122567.0  Wyoming, US
# 103801         106141.0  Wyoming, US
# 103802         228910.0  Wyoming, US
# 103803            202.0  Wyoming, US
#
# [103804 rows x 13 columns]

# %%
total_confirmed_vaccine_us['Date'].tolist()[-1]
# Out:
# '2021-10-23'

# %% [markdown]
# ### Update Data in the WORLD changed from 12.04.2020

# %%
print("Latest Update on the total vaccines already delivered\n")
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region']=='World']
# Out:
# Latest Update on the total vaccines already delivered
#     Province_State Country_Region        Date  Doses_admin  \
# 563            NaN          World  2021-10-24   6796392585
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 563                 3.748877e+09             2.858824e+09         2021-10-24
#
#      UID
# 563  NaN

# %%
# total_confirmed_vaccine_global.drop(total_confirmed_vaccine_global.tail(1).index,inplace=True) 
total_confirmed_vaccine_global
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 0              NaN    Afghanistan  2021-10-24      2566925
# 1              NaN        Albania  2021-10-24      1860335
# 2              NaN        Algeria  2021-10-24     14082920
# 3              NaN        Andorra  2021-10-24       102692
# 4              NaN         Angola  2021-10-24      5661085
# ..             ...            ...         ...          ...
# 561            NaN      Venezuela  2021-10-24     16127242
# 562            NaN        Vietnam  2021-10-24     71889209
# 563            NaN          World  2021-10-24   6796392585
# 564            NaN         Zambia  2021-10-24       871881
# 565            NaN       Zimbabwe  2021-10-24      5826876
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 0                   8.286010e+05             4.307440e+05         2021-10-24
# 1                   9.913710e+05             8.689640e+05         2021-10-24
# 2                   6.017036e+06             4.032942e+06         2021-10-24
# 3                   5.431200e+04             4.772000e+04         2021-10-24
# 4                   4.126328e+06             1.534757e+06         2021-10-24
# ..                           ...                      ...                ...
# 561                 9.926613e+06             6.190629e+06         2021-10-24
# 562                 5.115779e+07             2.073142e+07         2021-10-24
# 563                 3.748877e+09             2.858824e+09         2021-10-24
# 564                 3.110490e+05             5.110040e+05         2021-10-24
# 565                 3.276746e+06             2.550130e+06         2021-10-24
#
#        UID
# 0      4.0
# 1      8.0
# 2     12.0
# 3     20.0
# 4     24.0
# ..     ...
# 561  862.0
# 562  704.0
# 563    NaN
# 564  894.0
# 565  716.0
#
# [566 rows x 8 columns]

# %%
total_confirmed_vaccine_global[['Country_Region', 'Doses_admin']]
# Out:
#     Country_Region  Doses_admin
# 0      Afghanistan      2566925
# 1          Albania      1860335
# 2          Algeria     14082920
# 3          Andorra       102692
# 4           Angola      5661085
# ..             ...          ...
# 561      Venezuela     16127242
# 562        Vietnam     71889209
# 563          World   6796392585
# 564         Zambia       871881
# 565       Zimbabwe      5826876
#
# [566 rows x 2 columns]

# %%
total_confirmed_vaccine_global
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 0              NaN    Afghanistan  2021-10-24      2566925
# 1              NaN        Albania  2021-10-24      1860335
# 2              NaN        Algeria  2021-10-24     14082920
# 3              NaN        Andorra  2021-10-24       102692
# 4              NaN         Angola  2021-10-24      5661085
# ..             ...            ...         ...          ...
# 561            NaN      Venezuela  2021-10-24     16127242
# 562            NaN        Vietnam  2021-10-24     71889209
# 563            NaN          World  2021-10-24   6796392585
# 564            NaN         Zambia  2021-10-24       871881
# 565            NaN       Zimbabwe  2021-10-24      5826876
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 0                   8.286010e+05             4.307440e+05         2021-10-24
# 1                   9.913710e+05             8.689640e+05         2021-10-24
# 2                   6.017036e+06             4.032942e+06         2021-10-24
# 3                   5.431200e+04             4.772000e+04         2021-10-24
# 4                   4.126328e+06             1.534757e+06         2021-10-24
# ..                           ...                      ...                ...
# 561                 9.926613e+06             6.190629e+06         2021-10-24
# 562                 5.115779e+07             2.073142e+07         2021-10-24
# 563                 3.748877e+09             2.858824e+09         2021-10-24
# 564                 3.110490e+05             5.110040e+05         2021-10-24
# 565                 3.276746e+06             2.550130e+06         2021-10-24
#
#        UID
# 0      4.0
# 1      8.0
# 2     12.0
# 3     20.0
# 4     24.0
# ..     ...
# 561  862.0
# 562  704.0
# 563    NaN
# 564  894.0
# 565  716.0
#
# [566 rows x 8 columns]

# %%
for country in country_pop_dict.keys(): 
    total_confirmed_vaccine_global.loc[total_confirmed_vaccine_global['Country_Region']==country, 'Population'] = country_pop_dict[country]

total_confirmed_vaccine_global.loc[total_confirmed_vaccine_global['Country_Region']=='World', 'Population'] = 7674000000
total_confirmed_vaccine_global.loc[total_confirmed_vaccine_global['Country_Region']=='US (Aggregate)', 'Population'] = country_pop_dict['US']

total_confirmed_vaccine_global['ratio_vaccine_population'] = total_confirmed_vaccine_global['Doses_admin'] / total_confirmed_vaccine_global['Population']

# %%
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region'] == 'Denmark']
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 171            NaN        Denmark  2021-10-24      8829388
# 172  Faroe Islands        Denmark  2021-10-24        76516
# 173      Greenland        Denmark  2021-10-24        77006
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 171                    4470907.0                4402566.0         2021-10-24
# 172                          NaN                      NaN         2021-10-24
# 173                          NaN                      NaN         2021-10-24
#
#        UID  Population ratio_vaccine_population
# 171  208.0  5.7922e+06                  1.52436
# 172  234.0  5.7922e+06                0.0132102
# 173  304.0  5.7922e+06                0.0132948

# %%
# 4290071.0/5792200*100

# %%
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region'] == 'Germany']
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 205            NaN        Germany  2021-10-24    110785298
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 205                   57468294.0               55045227.0         2021-10-24
#
#        UID   Population ratio_vaccine_population
# 205  276.0  8.37839e+07                  1.32227

# %%
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region'] == 'Vietnam']
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 562            NaN        Vietnam  2021-10-24     71889209
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 562                   51157792.0               20731417.0         2021-10-24
#
#        UID   Population ratio_vaccine_population
# 562  704.0  9.73386e+07                 0.738548

# %%
total_confirmed_vaccine_global
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 0              NaN    Afghanistan  2021-10-24      2566925
# 1              NaN        Albania  2021-10-24      1860335
# 2              NaN        Algeria  2021-10-24     14082920
# 3              NaN        Andorra  2021-10-24       102692
# 4              NaN         Angola  2021-10-24      5661085
# ..             ...            ...         ...          ...
# 561            NaN      Venezuela  2021-10-24     16127242
# 562            NaN        Vietnam  2021-10-24     71889209
# 563            NaN          World  2021-10-24   6796392585
# 564            NaN         Zambia  2021-10-24       871881
# 565            NaN       Zimbabwe  2021-10-24      5826876
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 0                   8.286010e+05             4.307440e+05         2021-10-24
# 1                   9.913710e+05             8.689640e+05         2021-10-24
# 2                   6.017036e+06             4.032942e+06         2021-10-24
# 3                   5.431200e+04             4.772000e+04         2021-10-24
# 4                   4.126328e+06             1.534757e+06         2021-10-24
# ..                           ...                      ...                ...
# 561                 9.926613e+06             6.190629e+06         2021-10-24
# 562                 5.115779e+07             2.073142e+07         2021-10-24
# 563                 3.748877e+09             2.858824e+09         2021-10-24
# 564                 3.110490e+05             5.110040e+05         2021-10-24
# 565                 3.276746e+06             2.550130e+06         2021-10-24
#
#        UID   Population ratio_vaccine_population
# 0      4.0  3.89283e+07                0.0659397
# 1      8.0   2.8778e+06                 0.646443
# 2     12.0   4.3851e+07                 0.321154
# 3     20.0        77265                  1.32909
# 4     24.0  3.28663e+07                 0.172246
# ..     ...          ...                      ...
# 561  862.0  2.84359e+07                 0.567143
# 562  704.0  9.73386e+07                 0.738548
# 563    NaN   7674000000                 0.885639
# 564  894.0   1.8384e+07                0.0474262
# 565  716.0  1.48629e+07                 0.392041
#
# [566 rows x 10 columns]

# %%
total_confirmed_vaccine_global.sort_values(by='ratio_vaccine_population', ascending=False)[['Country_Region', 'ratio_vaccine_population']].groupby(by='Country_Region').max()
# Out:
#                 ratio_vaccine_population
# Country_Region
# Afghanistan                     0.065940
# Albania                         0.646443
# Algeria                         0.321154
# Andorra                         1.329088
# Angola                          0.172246
# ...                                  ...
# Venezuela                       0.567143
# Vietnam                         0.738548
# World                           0.885639
# Zambia                          0.047426
# Zimbabwe                        0.392041
#
# [165 rows x 1 columns]

# %%
total_confirmed_vaccine_global[['Country_Region', 'ratio_vaccine_population']].groupby(by='Country_Region').max().sort_values(by='ratio_vaccine_population', ascending=False).head(30)
# Out:
#                       ratio_vaccine_population
# Country_Region
# United Arab Emirates                  2.111847
# Malta                                 1.960006
# Uruguay                               1.885078
# Chile                                 1.829347
# Israel                                1.828545
# Palau                                 1.754331
# Singapore                             1.707514
# Qatar                                 1.668585
# Iceland                               1.663851
# Seychelles                            1.620826
# Cambodia                              1.614833
# Bahrain                               1.607910
# China                                 1.595065
# Portugal                              1.585206
# Canada                                1.535375
# Spain                                 1.524456
# Denmark                               1.524357
# Malaysia                              1.512228
# France                                1.499629
# Korea, South                          1.496799
# Belgium                               1.490346
# Ireland                               1.477834
# Italy                                 1.466778
# Norway                                1.460743
# Mongolia                              1.450009
# Japan                                 1.449630
# Finland                               1.445227
# Bhutan                                1.430131
# Sweden                                1.419420
# United Kingdom                        1.412793

# %%
total_confirmed_vaccine_global[['Country_Region', 'ratio_vaccine_population']].groupby(by='Country_Region').max().sort_values(by='ratio_vaccine_population', ascending=False).tail(30)
# Out:
#                   ratio_vaccine_population
# Country_Region
# Solomon Islands                   0.234097
# Eswatini                          0.233280
# Namibia                           0.229988
# Egypt                             0.226485
# Iraq                              0.211497
# Armenia                           0.209466
# Nicaragua                         0.197250
# Angola                            0.172246
# Guinea                            0.160660
# Togo                              0.155477
# Mozambique                        0.121559
# Senegal                           0.117126
# Cote d'Ivoire                     0.109650
# Gabon                             0.097768
# Kenya                             0.091178
# Ghana                             0.087779
# Gambia                            0.086226
# Afghanistan                       0.065940
# Uganda                            0.065379
# Malawi                            0.063227
# Syria                             0.051571
# Sierra Leone                      0.049667
# Sudan                             0.048145
# Zambia                            0.047426
# Nigeria                           0.039725
# Ethiopia                          0.035689
# Mali                              0.028876
# Papua New Guinea                  0.028434
# Cameroon                          0.018481
# South Sudan                       0.010978

# %%
countries_confirmed_by_day.iloc[-1]
# Out:
# Thailand             9742.0
# Haiti                   0.0
# Maldives              225.0
# Slovenia             2274.0
# Sudan                 154.0
#                       ...
# East Timor              0.0
# Azerbaijan           2315.0
# Georgia              4467.0
# Equatorial Guinea      69.0
# Others_and_ships        0.0
# Name: 640, Length: 229, dtype: float64

# %%
country = ['Luxembourg', 'Vietnam', 'Germany']
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region'].isin(country)]
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 205            NaN        Germany  2021-10-24    110785298
# 366            NaN     Luxembourg  2021-10-24       806150
# 562            NaN        Vietnam  2021-10-24     71889209
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 205                   57468294.0               55045227.0         2021-10-24
# 366                     424732.0                 399522.0         2021-10-24
# 562                   51157792.0               20731417.0         2021-10-24
#
#        UID   Population ratio_vaccine_population
# 205  276.0  8.37839e+07                  1.32227
# 366  442.0       625976                  1.28783
# 562  704.0  9.73386e+07                 0.738548

# %%
total_confirmed_vaccine_global.sort_values(by='Doses_admin', ascending=False).head(15).plot(x='Country_Region', y='Doses_admin', kind='bar')
plt.xticks(rotation=45)
total_confirmed_vaccine_global.sort_values(by='Doses_admin', ascending=False).head(15)
# Out:
#     Province_State  Country_Region        Date  Doses_admin  \
# 563            NaN           World  2021-10-24   6796392585
# 113            NaN           China  2021-10-24   2240550000
# 215            NaN           India  2021-10-24   1022267850
# 516            NaN              US  2021-10-24    412856169
# 517            NaN  US (Aggregate)  2021-10-24    411152284
# 64             NaN          Brazil  2021-10-24    268199870
# 316            NaN           Japan  2021-10-24    183344047
# 253            NaN       Indonesia  2021-10-24    180948208
# 250  Uttar Pradesh           India  2021-10-24    125438196
# 515            NaN          Turkey  2021-10-24    115164597
# 392            NaN          Mexico  2021-10-24    114558359
# 205            NaN         Germany  2021-10-24    110785298
# 445            NaN          Russia  2021-10-24    100766655
# 417            NaN        Pakistan  2021-10-24    100741762
# 201            NaN          France  2021-10-24     97886077
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 563                 3.748877e+09             2.858824e+09         2021-10-24
# 113                 1.100842e+09             1.047872e+09         2021-10-24
# 215                 7.140841e+08             2.995533e+08         2021-10-24
# 516                 2.201458e+08             1.904023e+08         2021-10-24
# 517                 2.201458e+08             1.904023e+08         2021-10-24
# 64                  1.582334e+08             1.147673e+08         2021-10-24
# 316                 9.640669e+07             8.693736e+07         2021-10-24
# 253                 1.122719e+08             6.716573e+07         2021-10-24
# 250                          NaN                      NaN         2021-10-24
# 515                 5.514424e+07             4.804349e+07         2021-10-24
# 392                 6.987979e+07             5.294997e+07         2021-10-24
# 205                 5.746829e+07             5.504523e+07         2021-10-24
# 445                 5.286135e+07             4.790530e+07         2021-10-24
# 417                 6.866646e+07             3.859689e+07         2021-10-24
# 201                 5.098717e+07             4.560606e+07         2021-10-24
#
#          UID   Population ratio_vaccine_population
# 563      NaN   7674000000                 0.885639
# 113    156.0  1.40468e+09                  1.59506
# 215    356.0     1.38e+09                 0.740771
# 516    840.0  3.29466e+08                  1.25311
# 517    840.0  3.29466e+08                  1.24793
# 64      76.0  2.12559e+08                  1.26176
# 316    392.0  1.26476e+08                  1.44963
# 253    360.0  2.73524e+08                 0.661545
# 250  35633.0     1.38e+09                 0.090897
# 515    792.0  8.43391e+07                   1.3655
# 392    484.0  1.27792e+08                 0.896442
# 205    276.0  8.37839e+07                  1.32227
# 445    643.0  1.45934e+08                 0.690493
# 417    586.0  2.20892e+08                 0.456067
# 201    250.0  6.52735e+07                  1.49963

# %%
countries = ['China', 'Germany', 'Italy', 'Japan', 'Australia', 'Luxembourg', 'US', 'United Kingdom', 'Canada', 'Vietnam', 'Philippines', 'Israel']

total_countries_vaccinated = total_confirmed_vaccine_global.groupby(by='Country_Region').sum()

# total_countries_vaccinated['vaccination_rate'] = total_countries_vaccinated['People_partially_vaccinated']/total_countries_vaccinated['Doses_admin']*100
total_countries_vaccinated['vaccination_speed']=total_countries_vaccinated.apply(lambda row: row.People_partially_vaccinated/row.Doses_admin*100, axis=1)
total_countries_vaccinated.sort_values(by='vaccination_speed', ascending=False)['vaccination_speed'].head(20).plot(kind='bar', title='Countries with high Vaccination Speed', color='lightgreen')
plt.xticks(rotation=45)
total_countries_vaccinated.sort_values(by='vaccination_speed', ascending=False).head(20)
# Out:
#                        Doses_admin  People_partially_vaccinated  \
# Country_Region
# Kuwait                     2380000                    2668082.0
# Gambia                      208379                     184817.0
# Eswatini                    270643                     236992.0
# Uganda                     2990507                    2575021.0
# Cameroon                    490604                     405846.0
# Sierra Leone                396196                     318380.0
# Syria                       902519                     681791.0
# Malawi                     1209535                     900023.0
# Ethiopia                   4102954                    3046441.0
# Solomon Islands             152832                     113423.0
# Cote d'Ivoire              2892373                    2122428.0
# Sao Tome and Principe       103720                      75837.0
# Angola                     5661085                    4126328.0
# Nicaragua                  1306694                     944476.0
# Taiwan*                   21717020                   15555520.0
# Kenya                      4902772                    3493570.0
# Vietnam                   71889209                   51157792.0
# Burma                     15797703                   11223285.0
# Laos                       4402770                    3091161.0
# Botswana                    882831                     618979.0
#
#                        People_fully_vaccinated    UID  vaccination_speed
# Country_Region
# Kuwait                                923307.0  414.0         112.104286
# Gambia                                171987.0  270.0          88.692719
# Eswatini                              229476.0  748.0          87.566277
# Uganda                                415486.0  800.0          86.106503
# Cameroon                              150894.0  120.0          82.723745
# Sierra Leone                          110744.0  694.0          80.359216
# Syria                                 367744.0  760.0          75.543119
total_confirmed_vaccine_global.sort_values(by='People_fully_vaccinated', ascending=False).head(20)
# Out:
#     Province_State  Country_Region        Date  Doses_admin  \
# 563            NaN           World  2021-10-24   6796392585
# 113            NaN           China  2021-10-24   2240550000
# 215            NaN           India  2021-10-24   1022267850
# 516            NaN              US  2021-10-24    412856169
# 517            NaN  US (Aggregate)  2021-10-24    411152284
# 64             NaN          Brazil  2021-10-24    268199870
# 316            NaN           Japan  2021-10-24    183344047
# 253            NaN       Indonesia  2021-10-24    180948208
# 205            NaN         Germany  2021-10-24    110785298
# 392            NaN          Mexico  2021-10-24    114558359
# 515            NaN          Turkey  2021-10-24    115164597
# 445            NaN          Russia  2021-10-24    100766655
# 201            NaN          France  2021-10-24     97886077
# 546            NaN  United Kingdom  2021-10-24     95908887
# 293            NaN           Italy  2021-10-24     88684107
# 417            NaN        Pakistan  2021-10-24    100741762
# 476            NaN           Spain  2021-10-24     71275614
# 98             NaN          Canada  2021-10-24     58122688
# 289            NaN            Iran  2021-10-24     77641350
# 511            NaN        Thailand  2021-10-24     69923540
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 563                 3.748877e+09             2.858824e+09         2021-10-24
# 113                 1.100842e+09             1.047872e+09         2021-10-24
# 215                 7.140841e+08             2.995533e+08         2021-10-24
# 516                 2.201458e+08             1.904023e+08         2021-10-24
# 517                 2.201458e+08             1.904023e+08         2021-10-24
# 64                  1.582334e+08             1.147673e+08         2021-10-24
# 316                 9.640669e+07             8.693736e+07         2021-10-24
# 253                 1.122719e+08             6.716573e+07         2021-10-24
# 205                 5.746829e+07             5.504523e+07         2021-10-24
# 392                 6.987979e+07             5.294997e+07         2021-10-24
# 515                 5.514424e+07             4.804349e+07         2021-10-24
# 445                 5.286135e+07             4.790530e+07         2021-10-24
# 201                 5.098717e+07             4.560606e+07         2021-10-24
# 546                 4.960642e+07             4.548998e+07         2021-10-24
# 293                 4.645638e+07             4.270892e+07         2021-10-24
# 417                 6.866646e+07             3.859689e+07         2021-10-24
# 476                 3.795403e+07             3.719958e+07         2021-10-24
# 98                  2.969463e+07             2.797654e+07         2021-10-24
# 289                 5.003642e+07             2.760493e+07         2021-10-24
# 511                 3.813710e+07             2.647452e+07         2021-10-24
#
#        UID   Population ratio_vaccine_population
# 563    NaN   7674000000                 0.885639
# 113  156.0  1.40468e+09                  1.59506
# 215  356.0     1.38e+09                 0.740771
# 516  840.0  3.29466e+08                  1.25311
# 517  840.0  3.29466e+08                  1.24793
# 64    76.0  2.12559e+08                  1.26176
# 316  392.0  1.26476e+08                  1.44963
# 253  360.0  2.73524e+08                 0.661545
# 205  276.0  8.37839e+07                  1.32227
# 392  484.0  1.27792e+08                 0.896442
# 515  792.0  8.43391e+07                   1.3655
# 445  643.0  1.45934e+08                 0.690493
# 201  250.0  6.52735e+07                  1.49963
# 546  826.0   6.7886e+07                  1.41279
# 293  380.0  6.04618e+07                  1.46678
# 417  586.0  2.20892e+08                 0.456067
# 476  724.0  4.67548e+07                  1.52446
# 98   124.0  3.78557e+07                  1.53537
# 289  364.0   8.3993e+07                 0.924379
# 511  764.0     6.98e+07                  1.00177

# %%
# TODO: check correlation between total vaccines vs population, total vaccines vs confirmed cases, total vaccines vs death cases
