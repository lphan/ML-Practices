# %% [markdown]
# ### COVID-19
# ### Number of FATALITIES updated by DAY
# ### in the countries: CHINA, GERMANY, ITALY, KOREA, JAPAN, USA, AUSTRALIA

# %%
# Configuration: setup absolute path to location of package Starts and config-file 
from inspect import getsourcefile
import os.path as path, sys
current_dir = path.dirname(path.abspath(getsourcefile(lambda:0)))
sys.path.insert(0, current_dir[:current_dir.rfind(path.sep)])

from Starts.start import *
from Starts.startml import *
from Starts.startvis import *  
# %matplotlib inline
rcParams['figure.figsize'] = 20, 6
# Out:
# C:\Users\Duc-LongPhan\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# Using TensorFlow backend.
# Start importing files in folder
# ['.gitignore', '01-22-2020.csv', '01-23-2020.csv', '01-24-2020.csv', '01-25-2020.csv', '01-26-2020.csv', '01-27-2020.csv', '01-28-2020.csv', '01-29-2020.csv', '01-30-2020.csv', '01-31-2020.csv', '02-01-2020.csv', '02-02-2020.csv', '02-03-2020.csv', '02-04-2020.csv', '02-05-2020.csv', '02-06-2020.csv', '02-07-2020.csv', '02-08-2020.csv', '02-09-2020.csv', '02-10-2020.csv', '02-11-2020.csv', '02-12-2020.csv', '02-13-2020.csv', '02-14-2020.csv', '02-15-2020.csv', '02-16-2020.csv', '02-17-2020.csv', '02-18-2020.csv', '02-19-2020.csv', '02-20-2020.csv', '02-21-2020.csv', '02-22-2020.csv', '02-23-2020.csv', '02-24-2020.csv', '02-25-2020.csv', '02-26-2020.csv', '02-27-2020.csv', '02-28-2020.csv', '02-29-2020.csv', '03-01-2020.csv', '03-02-2020.csv', '03-03-2020.csv', '03-04-2020.csv', '03-05-2020.csv', '03-06-2020.csv', '03-07-2020.csv', '03-08-2020.csv', '03-09-2020.csv', '03-10-2020.csv', '03-11-2020.csv', '03-12-2020.csv', '03-13-2020.csv', '03-14-2020.csv', '03-15-2020.csv', '03-16-2020.csv', '03-17-2020.csv', '03-18-2020.csv', '03-19-2020.csv', '03-20-2020.csv', '03-21-2020.csv', '03-22-2020.csv', '03-23-2020.csv', '03-24-2020.csv', '03-25-2020.csv', '03-26-2020.csv', '03-27-2020.csv', '03-28-2020.csv', '03-29-2020.csv', '03-30-2020.csv', '03-31-2020.csv', '04-01-2020.csv', '04-02-2020.csv', '04-03-2020.csv', '04-04-2020.csv', '04-05-2020.csv', '04-06-2020.csv', '04-07-2020.csv', '04-08-2020.csv', '04-09-2020.csv', '04-10-2020.csv', '04-11-2020.csv', '04-12-2020.csv', '04-13-2020.csv', '04-14-2020.csv', '04-15-2020.csv', '04-16-2020.csv', '04-17-2020.csv', '04-18-2020.csv', '04-19-2020.csv', '04-20-2020.csv', '04-21-2020.csv', '04-22-2020.csv', '04-23-2020.csv', '04-24-2020.csv', '04-25-2020.csv', '04-26-2020.csv', '04-27-2020.csv', '04-28-2020.csv', '04-29-2020.csv', 'README.md']
# None
# None
# Start importing single data  ./COVID-19/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv

# %% [markdown]
# ### Number of covid-19 outbreak days

# %%
from covid import *
len(data)
# Out:
# C:\Users\Duc-LongPhan\Anaconda3\lib\site-packages\pandas\core\strings.py:1843: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# C:\Users\Duc-LongPhan\Desktop\CodeRepo\lphan\ML-Practices\18_Covid-19\covid.py:323: RuntimeWarning: invalid value encountered in long_scalars
#   y_dat_ratioDeathConf[country] = y_dat_deaths[country][-1]/y_dat_confirmed[country][-1]*100
# C:\Users\Duc-LongPhan\Desktop\CodeRepo\lphan\ML-Practices\18_Covid-19\covid.py:328: RuntimeWarning: invalid value encountered in long_scalars
#   y_dat_ratioRecPop[country] = y_dat_recovered[country][-1]/y_dat_confirmed[country][-1]*100
# 99

# %% [markdown]
# ### Number of FATALITIES in the first outbreak day

# %%
y_dat_all_fatal[0]
# Out:
# 17.0

# %% [markdown]
# ### Number of FATALITIES in the latest outbreak day

# %%
y_dat_all_fatal[-1]
# Out:
# 227638

# %% [markdown]
# ### Number of countries at the first day where fatalities occur

# %%
np.unique(data[0][data[0]['Deaths']>0].filter(regex=("Country.*")).values), len(np.unique(data[0][data[0]['Deaths']>0].filter(regex=("Country.*")).values))
# Out:
# (array(['Mainland China'], dtype=object), 1)

# %% [markdown]
# ### Number of countries at the latest day where fatalities occur

# %%
np.unique(data[-1][data[-1]['Deaths']>0].filter(regex=("Country.*")).values), len(np.unique(data[-1][data[-1]['Deaths']>0].filter(regex=("Country.*")).values))
# Out:
# (array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#         'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#         'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#         'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bolivia',
#         'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei',
#         'Bulgaria', 'Burkina Faso', 'Burma', 'Burundi', 'Cabo Verde',
#         'Cameroon', 'Canada', 'Chad', 'Chile', 'China', 'Colombia',
#         'Congo (Brazzaville)', 'Congo (Kinshasa)', 'Costa Rica',
#         "Cote d'Ivoire", 'Croatia', 'Cuba', 'Cyprus', 'Czechia', 'Denmark',
#         'Diamond Princess', 'Djibouti', 'Dominican Republic', 'Ecuador',
#         'Egypt', 'El Salvador', 'Equatorial Guinea', 'Estonia', 'Eswatini',
#         'Ethiopia', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia',
#         'Germany', 'Ghana', 'Greece', 'Guatemala', 'Guinea',
#         'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'Hungary',
#         'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland',
#         'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan',
#         'Kenya', 'Korea, South', 'Kosovo', 'Kuwait', 'Kyrgyzstan',
#         'Latvia', 'Lebanon', 'Liberia', 'Libya', 'Liechtenstein',
#         'Lithuania', 'Luxembourg', 'MS Zaandam', 'Malawi', 'Malaysia',
#         'Maldives', 'Mali', 'Malta', 'Mauritania', 'Mauritius', 'Mexico',
#         'Moldova', 'Monaco', 'Montenegro', 'Morocco', 'Netherlands',
#         'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'North Macedonia',
#         'Norway', 'Oman', 'Pakistan', 'Panama', 'Paraguay', 'Peru',
#         'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia',
#         'San Marino', 'Saudi Arabia', 'Senegal', 'Serbia', 'Sierra Leone',
#         'Singapore', 'Slovakia', 'Slovenia', 'Somalia', 'South Africa',
#         'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Sweden', 'Switzerland',
#         'Syria', 'Taiwan*', 'Tanzania', 'Thailand', 'Togo',
#         'Trinidad and Tobago', 'Tunisia', 'Turkey', 'US', 'Ukraine',
#         'United Arab Emirates', 'United Kingdom', 'Uruguay', 'Uzbekistan',
#         'Venezuela', 'West Bank and Gaza', 'Zambia', 'Zimbabwe'],
#        dtype=object), 158)

# %% [markdown]
# ### New Fatalities in the World changed by day

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.bar(x_dat, newFatalitiesByDay, color='red')
plt.xlabel('Days')
plt.ylabel('New Fatalities cases')
# Out:
# Text(0, 0.5, 'New Fatalities cases')

# %% [markdown]
# ### Number of FATALITIES in the World from day 0 to latest day

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.plot(x_dat, y_dat_all_fatal, color='red')
plt.xlabel('Days')
plt.ylabel('Fatalities cases')
('Last day Increasing', y_dat_all_fatal[-1]-y_dat_all_fatal[-2]), ('Total Confirmed', y_dat_all_fatal[-1])
# Out:
# (('Last day Increasing', 10485), ('Total Confirmed', 227638))

# %% [markdown]
# ### Number of FATALITIES in CHINA from day 0 to latest day

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.bar(x_dat, y_dat_deaths['China'], color='red')
plt.legend(["China"])

plt.xlabel('Days')
plt.ylabel('Fatalities cases')
('Last day Increasing', y_dat_deaths['China'][-1]-y_dat_deaths['China'][-2]), ('Total Confirmed', y_dat_deaths['China'][-1])
# Out:
# (('Last day Increasing', 0), ('Total Confirmed', 4637))

# %% [markdown]
# ### Number of FATALITIES in GERMANY from day 0 to latest day

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.bar(x_dat, y_dat_deaths['Germany'], color='red')
plt.legend(["GERMANY"])

# plt.yticks(np.arange(0, max(y_dat_deaths['Germany'])+1, 1))
plt.xlabel('Days')
plt.ylabel('Fatalities cases')
('Last day Increasing', y_dat_deaths['Germany'][-1]-y_dat_deaths['Germany'][-2]), ('Total Confirmed', y_dat_deaths['Germany'][-1])
# Out:
# (('Last day Increasing', 153), ('Total Confirmed', 6467))

# %% [markdown]
# ### Number of FATALITIES in ITALY from day 0 to latest day

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.bar(x_dat, y_dat_deaths['Italy'], color='red')
plt.legend(["ITALY"])

plt.xlabel('Days')
plt.ylabel('Fatalities cases')
('Last day Increasing', y_dat_deaths['Italy'][-1]-y_dat_deaths['Italy'][-2]), ('Total Confirmed', y_dat_deaths['Italy'][-1])
# Out:
# (('Last day Increasing', 323), ('Total Confirmed', 27682))

# %% [markdown]
# ### Number of FATALITIES in SOUTH KOREA from day 0 to latest day

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.bar(x_dat, y_dat_deaths['Korea, South'], color='red')
plt.legend(["SOUTH KOREA"])

plt.xlabel('Days')
plt.ylabel('Fatalities cases')
('Last day Increasing', y_dat_deaths['Korea, South'][-1]-y_dat_deaths['Korea, South'][-2]), ('Total Confirmed', y_dat_deaths['Korea, South'][-1])
# Out:
# (('Last day Increasing', 1), ('Total Confirmed', 247))

# %% [markdown]
# ### Number of FATALITIES in JAPAN from day 0 to latest day

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.bar(x_dat, y_dat_deaths['Japan'], color='red')
plt.legend(["JAPAN"])

plt.xlabel('Days')
plt.ylabel('Fatalities cases')
('Last day Increasing', y_dat_deaths['Japan'][-1]-y_dat_deaths['Japan'][-2]), ('Total Confirmed', y_dat_deaths['Japan'][-1])
# Out:
# (('Last day Increasing', 19), ('Total Confirmed', 413))

# %% [markdown]
# #### Note: it seems there was bias about number of fatalities at day 47 in Japan. At current day (day 48), there's 10 cases.

# %% [markdown]
# ### Number of FATALITIES in the USA from day 0 to latest day

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))

plt.bar(x_dat, y_dat_deaths['US'], color='red')
plt.legend(["USA"])

plt.xlabel('Days')
plt.ylabel('Fatalities cases')
('Last day Increasing', y_dat_deaths['US'][-1]-y_dat_deaths['US'][-2]), ('Total Confirmed', y_dat_deaths['US'][-1])
# Out:
# (('Last day Increasing', 2612), ('Total Confirmed', 60967))

# %% [markdown]
# ### Number of FATALITIES in the Australia from day 0 to latest day

# %%
plt.xticks(np.arange(0, max(x_dat)+1, 2))
plt.bar(x_dat, y_dat_deaths['Australia'], color='red')
plt.legend(["Australia"])

plt.yticks(np.arange(0, max(y_dat_deaths['Australia'])+1, 5))
plt.xlabel('Days')
plt.ylabel('Fatalities cases')
('Last day Increasing', y_dat_deaths['Australia'][-1]-y_dat_deaths['Australia'][-2]), ('Total Confirmed', y_dat_deaths['Australia'][-1])
# Out:
# (('Last day Increasing', 2), ('Total Confirmed', 91))

# %% [markdown]
# #### Note: it seems there was bias about number of fatalities at day 46-47 in Australia. At days day 48-49, there's 3 cases.
