# %%
from covid_import import *
from vaccine_import import *
# %matplotlib inline
# Out:
# Start importing World-data  ./COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/
# Start importing USA-data  ./COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/
# Start importing single data  ./COVID-19/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv
# Start importing single data  ./COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# Start importing single data  ./COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# Start importing single data  ./COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv
# Start importing single data vaccine in US ./Vaccine/COVID-19/data_tables/vaccine_data/raw_data/vaccine_data_us_state_timeline.csv
# Start importing single data vaccine in the World ./Vaccine/COVID-19/data_tables/vaccine_data/global_data/vaccine_data_global.csv

# %%
rcParams['figure.figsize'] = 20, 6

# %% [markdown]
# ### Update Data in the WORLD changed from 12.04.2020

# %%
print("Latest Update on the total vaccines already delivered\n")
total_confirmed_vaccine_global.tail(1)
# Out:
# Latest Update on the total vaccines already delivered
#    Country_Region        Date  Doses_admin  People_partially_vaccinated  \
# 81          World  2021-02-05  123544056.0                   96424727.0
#
#     People_fully_vaccinated Report_Date_String  UID
# 81               15180649.0         2021/02/05  NaN

# %%
total_confirmed_vaccine_global.drop(total_confirmed_vaccine_global.tail(1).index,inplace=True) 
total_confirmed_vaccine_global
# Out:
#           Country_Region        Date  Doses_admin  \
# 0                Algeria  2021-01-30         30.0
# 1                Andorra  2021-02-01       1036.0
# 2              Argentina  2021-02-04     444018.0
# 3                Austria  2021-02-05     252829.0
# 4                Bahrain  2021-02-05     179550.0
# ..                   ...         ...          ...
# 76                Turkey  2021-02-05    2559802.0
# 77  United Arab Emirates  2021-02-04    3849374.0
# 78        United Kingdom  2021-02-04   11477040.0
# 79         United States  2021-02-06   36819212.0
# 80                 Wales  2021-02-04     524677.0
#
#     People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 0                           0.0                      0.0         2021/01/30
# 1                        1036.0                      0.0         2021/02/01
# 2                      297717.0                 146301.0         2021/02/04
# 3                      202160.0                  50669.0         2021/02/05
# 4                      179550.0                      0.0         2021/02/05
# ..                          ...                      ...                ...
# 76                          0.0                      0.0         2021/02/05
# 77                    3599374.0                 250000.0         2021/02/04
# 78                   10971047.0                 505993.0         2021/02/04
# 79                   28909497.0                7503864.0         2021/02/06
# 80                     523042.0                   1635.0         2021/02/04
#
#         UID
# 0      12.0
# 1      20.0
# 2      32.0
# 3      40.0
# 4      48.0
# ..      ...
# 76    792.0
# 77    784.0
# 78    826.0
# 79    840.0
# 80  82604.0
#
# [81 rows x 7 columns]

# %%
total_confirmed_vaccine_global.sort_values(by='Doses_admin', ascending=False).plot(x='Country_Region', y='Doses_admin', kind='bar')
total_confirmed_vaccine_global.sort_values(by='Doses_admin', ascending=False).head(10)
# Out:
#           Country_Region        Date  Doses_admin  \
# 79         United States  2021-02-06   36819212.0
# 14                 China  2021-02-03   31200000.0
# 24        European Union  2021-02-05   16222844.0
# 78        United Kingdom  2021-02-04   11477040.0
# 22               England  2021-02-04    9899043.0
# 35                 India  2021-02-05    5416849.0
# 39                Israel  2021-02-05    5376768.0
# 77  United Arab Emirates  2021-02-04    3849374.0
# 28               Germany  2021-02-05    3116122.0
# 9                 Brazil  2021-02-05    3074906.0
#
#     People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 79                   28909497.0                7503864.0         2021/02/06
# 14                   31200000.0                      0.0         2021/02/03
# 24                   11475802.0                4390525.0         2021/02/05
# 78                   10971047.0                 505993.0         2021/02/04
# 22                    9430261.0                 468782.0         2021/02/04
# 35                          0.0                      0.0         2021/02/05
# 39                    3390398.0                1986370.0         2021/02/05
# 77                    3599374.0                 250000.0         2021/02/04
# 28                    2212851.0                 903271.0         2021/02/05
# 9                     3074906.0                      0.0         2021/02/05
#
#         UID
# 79    840.0
# 14    156.0
# 24      NaN
# 78    826.0
# 22  82601.0
# 35    356.0
# 39    376.0
# 77    784.0
# 28    276.0
# 9      76.0

# %%
total_confirmed_vaccine_global.sort_values(by='People_partially_vaccinated', ascending=False).plot(x='Country_Region', y='People_partially_vaccinated', kind='bar')
total_confirmed_vaccine_global.sort_values(by='People_partially_vaccinated', ascending=False).head(10)
# Out:
#           Country_Region        Date  Doses_admin  \
# 14                 China  2021-02-03   31200000.0
# 79         United States  2021-02-06   36819212.0
# 24        European Union  2021-02-05   16222844.0
# 78        United Kingdom  2021-02-04   11477040.0
# 22               England  2021-02-04    9899043.0
# 77  United Arab Emirates  2021-02-04    3849374.0
# 39                Israel  2021-02-05    5376768.0
# 9                 Brazil  2021-02-05    3074906.0
# 28               Germany  2021-02-05    3116122.0
# 27                France  2021-02-04    1962126.0
#
#     People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 14                   31200000.0                      0.0         2021/02/03
# 79                   28909497.0                7503864.0         2021/02/06
# 24                   11475802.0                4390525.0         2021/02/05
# 78                   10971047.0                 505993.0         2021/02/04
# 22                    9430261.0                 468782.0         2021/02/04
# 77                    3599374.0                 250000.0         2021/02/04
# 39                    3390398.0                1986370.0         2021/02/05
# 9                     3074906.0                      0.0         2021/02/05
# 28                    2212851.0                 903271.0         2021/02/05
# 27                    1772602.0                 189524.0         2021/02/04
#
#         UID
# 14    156.0
# 79    840.0
# 24      NaN
# 78    826.0
# 22  82601.0
# 77    784.0
# 39    376.0
# 9      76.0
# 28    276.0
# 27    250.0

# %%
total_confirmed_vaccine_global.sort_values(by='People_fully_vaccinated', ascending=False).plot(x='Country_Region', y='People_fully_vaccinated', kind='bar')
total_confirmed_vaccine_global.sort_values(by='People_fully_vaccinated', ascending=False).head(10)
# Out:
#           Country_Region        Date  Doses_admin  \
# 79         United States  2021-02-06   36819212.0
# 24        European Union  2021-02-05   16222844.0
# 39                Israel  2021-02-05    5376768.0
# 40                 Italy  2021-02-05    2435489.0
# 28               Germany  2021-02-05    3116122.0
# 72                 Spain  2021-02-04    1988160.0
# 78        United Kingdom  2021-02-04   11477040.0
# 22               England  2021-02-04    9899043.0
# 60                Poland  2021-02-05    1617764.0
# 77  United Arab Emirates  2021-02-04    3849374.0
#
#     People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 79                   28909497.0                7503864.0         2021/02/06
# 24                   11475802.0                4390525.0         2021/02/05
# 39                    3390398.0                1986370.0         2021/02/05
# 40                    1400437.0                1035052.0         2021/02/05
# 28                    2212851.0                 903271.0         2021/02/05
# 72                    1305251.0                 682909.0         2021/02/04
# 78                   10971047.0                 505993.0         2021/02/04
# 22                    9430261.0                 468782.0         2021/02/04
# 60                    1193034.0                 424730.0         2021/02/05
# 77                    3599374.0                 250000.0         2021/02/04
#
#         UID
# 79    840.0
# 24      NaN
# 39    376.0
# 40    380.0
# 28    276.0
# 72    724.0
# 78    826.0
# 22  82601.0
# 60    616.0
# 77    784.0
