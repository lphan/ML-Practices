# %%
from covid_import import *
from vaccine_import import *
# %matplotlib inline
# Out:
# Start importing World-data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/
# Start importing USA-data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/
# Start importing single data  ./data/COVID-19/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv
# Start importing single data vaccine in US ./data/Vaccine/COVID-19/data_tables/vaccine_data/us_data/time_series/vaccine_data_us_timeline.csv
# Start importing single data vaccine in the World ./data/Vaccine/COVID-19/data_tables/vaccine_data/global_data/vaccine_data_global.csv
# ...

# %%
rcParams['figure.figsize'] = 20, 6
total_confirmed_vaccine_global['Date'].max()
# Out:
# '2021-06-20'

# %%
total_confirmed_vaccine_us
# Out:
#       Province_State        Date Vaccine_Type  FIPS Country_Region      Lat  \
# 0            Alabama  2020-12-10          All   1.0             US  32.3182
# 1            Alabama  2020-12-10      Moderna   1.0             US  32.3182
# 2            Alabama  2020-12-10       Pfizer   1.0             US  32.3182
# 3            Alabama  2020-12-11          All   1.0             US  32.3182
# 4            Alabama  2020-12-11      Moderna   1.0             US  32.3182
# ...              ...         ...          ...   ...            ...      ...
# 57683        Wyoming  2021-06-19      Janssen  56.0             US  42.7560
# 57684        Wyoming  2021-06-19       Pfizer  56.0             US  42.7560
# 57685        Wyoming  2021-06-19      Moderna  56.0             US  42.7560
# 57686        Wyoming  2021-06-19          All  56.0             US  42.7560
# 57687        Wyoming  2021-06-19   Unassigned  56.0             US  42.7560
#
# ...

# %%
total_confirmed_vaccine_us['Date'].tolist()[-1]
# Out:
# '2021-06-19'

# %% [markdown]
# ### Update Data in the WORLD changed from 12.04.2020

# %%
print("Latest Update on the total vaccines already delivered\n")
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region']=='World']
# Out:
# Latest Update on the total vaccines already delivered
#     Province_State Country_Region        Date  Doses_admin  \
# 424            NaN          World  2021-06-20   2597090310
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 424                 1.665726e+09              760907202.0         2021/06/20
#
#      UID
# 424  NaN

# %%
# total_confirmed_vaccine_global.drop(total_confirmed_vaccine_global.tail(1).index,inplace=True) 
total_confirmed_vaccine_global
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 0              NaN    Afghanistan  2021-06-20       662003
# 1              NaN        Albania  2021-06-20       862628
# 2              NaN        Algeria  2021-06-20      2500000
# 3              NaN        Andorra  2021-06-20        51114
# 4              NaN         Angola  2021-06-20      1314375
# ..             ...            ...         ...          ...
# 422            NaN      Venezuela  2021-06-20      1302992
# 423            NaN        Vietnam  2021-06-20      2359376
# 424            NaN          World  2021-06-20   2597090310
# 425            NaN         Zambia  2021-06-20       148304
# 426            NaN       Zimbabwe  2021-06-20      1109365
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 0                   4.847370e+05                 177266.0         2021/06/20
# 1                   5.111750e+05                 351453.0         2021/06/20
# ...

# %%
country = ['Luxembourg', 'Vietnam', 'Germany']
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region'].isin(country)]
# Out:
#     Province_State Country_Region        Date  Doses_admin  \
# 179            NaN        Germany  2021-06-20     65738489
# 266            NaN     Luxembourg  2021-06-20       468346
# 423            NaN        Vietnam  2021-06-20      2359376
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 179                   42065100.0               25301843.0         2021/06/20
# 266                     283338.0                 185008.0         2021/06/20
# 423                    2244061.0                 115315.0         2021/06/20
#
#        UID
# 179  276.0
# 266  442.0
# 423  704.0

# %%
total_confirmed_vaccine_global.sort_values(by='Doses_admin', ascending=False).head(15).plot(x='Country_Region', y='Doses_admin', kind='bar')
plt.xticks(rotation=45)
total_confirmed_vaccine_global.sort_values(by='Doses_admin', ascending=False).head(15)
# Out:
#     Province_State  Country_Region        Date  Doses_admin  \
# 424            NaN           World  2021-06-20   2597090310
# 103            NaN           China  2021-06-20   1010489000
# 376            NaN              US  2021-06-20    317117797
# 377            NaN  US (Aggregate)  2021-06-20    316653275
# 189            NaN           India  2021-06-20    276693572
# 55             NaN          Brazil  2021-06-20     80986713
# 407            NaN  United Kingdom  2021-06-20     74378751
# 179            NaN         Germany  2021-06-20     65738489
# 411        England  United Kingdom  2021-06-20     61964858
# 175            NaN          France  2021-06-20     47714865
# 231            NaN           Italy  2021-06-20     45579305
# 375            NaN          Turkey  2021-06-20     41261482
# 275            NaN          Mexico  2021-06-20     39623088
# 337            NaN           Spain  2021-06-20     35412140
# 226            NaN       Indonesia  2021-06-20     35086248
#
# ...

# %%
countries = ['China', 'Germany', 'Italy', 'Korea, South', 'Japan', 'Australia', 'Luxembourg', 'US', 'United Kingdom', 'Canada', 'Vietnam', 'Philippines', 'Israel']

total_confirmed_vaccine_global.loc[total_confirmed_vaccine_global['Country_Region'].isin(countries)].groupby(by='Country_Region').sum().sort_values(by='Doses_admin', ascending=False)
# Out:
#                 Doses_admin  People_partially_vaccinated  \
# Country_Region
# China            1013958260                  622000000.0
# US                317117797                  176737141.0
# United Kingdom    148512002                   42679268.0
# Italy              91158610                   31209990.0
# Germany            65738489                   42065100.0
# Canada             63672756                   25043879.0
# Japan              28887137                   20763123.0
# Israel             10640916                    5491534.0
# Philippines         8050711                    5953810.0
# Australia           6491476                    5650274.0
# Vietnam             2359376                    2244061.0
# Luxembourg           468346                     283338.0
#
#                 People_fully_vaccinated       UID
# Country_Region
# China                       223299000.0     946.0
# US                          149125164.0     840.0
# ...

# %%
total_confirmed_vaccine_global.sort_values(by='People_partially_vaccinated', ascending=False).head(15).plot(x='Country_Region', y='People_partially_vaccinated', kind='bar')
plt.xticks(rotation=45)
total_confirmed_vaccine_global.sort_values(by='People_partially_vaccinated', ascending=False).head(15)
# Out:
#     Province_State  Country_Region        Date  Doses_admin  \
# 424            NaN           World  2021-06-20   2597090310
# 103            NaN           China  2021-06-20   1010489000
# 189            NaN           India  2021-06-20    276693572
# 377            NaN  US (Aggregate)  2021-06-20    316653275
# 376            NaN              US  2021-06-20    317117797
# 55             NaN          Brazil  2021-06-20     80986713
# 407            NaN  United Kingdom  2021-06-20     74378751
# 179            NaN         Germany  2021-06-20     65738489
# 175            NaN          France  2021-06-20     47714865
# 231            NaN           Italy  2021-06-20     45579305
# 275            NaN          Mexico  2021-06-20     39623088
# 375            NaN          Turkey  2021-06-20     41261482
# 88             NaN          Canada  2021-06-20     31836378
# 226            NaN       Indonesia  2021-06-20     35086248
# 337            NaN           Spain  2021-06-20     35412140
#
# ...

# %%
total_confirmed_vaccine_global.sort_values(by='People_fully_vaccinated', ascending=False).head(15).plot(x='Country_Region', y='People_fully_vaccinated', kind='bar')
plt.xticks(rotation=45)
total_confirmed_vaccine_global.sort_values(by='People_fully_vaccinated', ascending=False).head(15)
# Out:
#     Province_State  Country_Region        Date  Doses_admin  \
# 424            NaN           World  2021-06-20   2597090310
# 103            NaN           China  2021-06-20   1010489000
# 376            NaN              US  2021-06-20    317117797
# 377            NaN  US (Aggregate)  2021-06-20    316653275
# 189            NaN           India  2021-06-20    276693572
# 407            NaN  United Kingdom  2021-06-20     74378751
# 179            NaN         Germany  2021-06-20     65738489
# 55             NaN          Brazil  2021-06-20     80986713
# 175            NaN          France  2021-06-20     47714865
# 275            NaN          Mexico  2021-06-20     39623088
# 231            NaN           Italy  2021-06-20     45579305
# 319            NaN          Russia  2021-06-20     34901304
# 375            NaN          Turkey  2021-06-20     41261482
# 337            NaN           Spain  2021-06-20     35412140
# 226            NaN       Indonesia  2021-06-20     35086248
#
# ...

# %%
# Countries which have the fastest vaccines doses
rcParams['figure.figsize'] = 20, 10
countries = ['Germany', 'Australia', 'Luxembourg', 'US', 'Vietnam']
for country in countries:    
    plt.plot(range(len(time_series_vaccine_global[time_series_vaccine_global['Country_Region']==country])), 
                      time_series_vaccine_global[time_series_vaccine_global['Country_Region']==country]['Doses_admin'], label=country)
    
plt.title("Time series data vaccine progress")
plt.legend()
