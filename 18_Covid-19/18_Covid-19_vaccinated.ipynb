# %%
from covid_import import *
from vaccine_import import *
# %matplotlib inline
# Out:
# Start importing World-data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/
# Start importing USA-data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/
# Start importing single data  ./data/COVID-19/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# Start importing single data  ./data/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv
# Start importing single data vaccine in US ./data/Vaccine/COVID-19/data_tables/vaccine_data/us_data/time_series/vaccine_data_us_timeline.csv
# Start importing single data vaccine in the World ./data/Vaccine/COVID-19/data_tables/vaccine_data/global_data/vaccine_data_global.csv
# Start importing time series data vaccine in the World ./data/Vaccine/COVID-19/data_tables/vaccine_data/global_data/time_series_covid19_vaccine_global.csv

# %%
rcParams['figure.figsize'] = 20, 6
total_confirmed_vaccine_global['Date'].max()
# Out:
# '2021-12-01'

# %%
total_confirmed_vaccine_us.groupby(by='Province_State').max()
# Out:
#                       Date Vaccine_Type  FIPS Country_Region      Lat  \
# Province_State
# Alabama         2021-11-30      unknown   1.0             US  32.3182
# Alaska          2021-11-30      unknown   2.0             US  61.3707
# American Samoa  2021-11-30      unknown  60.0             US -14.2710
# Arizona         2021-11-30      unknown   4.0             US  33.7298
# Arkansas        2021-11-30      unknown   5.0             US  34.9697
# ...                    ...          ...   ...            ...      ...
# Virginia        2021-11-30      unknown  51.0             US  37.7693
# Washington      2021-11-30      unknown  53.0             US  47.4009
# West Virginia   2021-11-30      unknown  54.0             US  38.4912
# Wisconsin       2021-11-30      unknown  55.0             US  44.2685
# Wyoming         2021-11-30      unknown  56.0             US  42.7560
#
#                    Long_  Doses_alloc  Doses_shipped  Doses_admin  \
# Province_State
# Alabama         -86.9023     640150.0      7847520.0    5242493.0
# Alaska         -152.4044     508630.0      1272385.0     957508.0
# American Samoa -170.1320      29450.0        75120.0      67867.0
# Arizona        -111.4312    1610310.0     11729770.0    9594424.0
# Arkansas        -92.3731    2035270.0      4877430.0    3524081.0
# ...                  ...          ...            ...          ...
# Virginia        -78.1700    1387775.0     15628535.0   13100880.0
# Washington     -121.4905    1208600.0     13976625.0   11377078.0
# West Virginia   -80.9545     520535.0      3381025.0    1942160.0
# Wisconsin       -89.6165    6809515.0      9291735.0    8194809.0
# Wyoming        -107.3025     101650.0       814305.0     632809.0
#
#                 Stage_One_Doses  Stage_Two_Doses        Combined_Key
# Province_State
# Alabama               2772024.0        2132454.0         Alabama, US
# Alaska                 459412.0         363423.0          Alaska, US
# American Samoa          35585.0          30849.0  American Samoa, US
# Arizona               4680309.0        3703007.0         Arizona, US
# Arkansas              1824522.0        1395348.0        Arkansas, US
# ...                         ...              ...                 ...
# Virginia              6451445.0        5208914.0        Virginia, US
# Washington            5552276.0        4596495.0      Washington, US
# West Virginia          966073.0         699292.0   West Virginia, US
# Wisconsin             3832519.0        3231440.0       Wisconsin, US
# Wyoming                310481.0         241969.0         Wyoming, US
#
# [65 rows x 12 columns]

# %%
total_confirmed_vaccine_us['Date'].tolist()[-1]
# Out:
# '2021-11-30'

# %% [markdown]
# ### Update Data in the WORLD changed from 12.04.2020

# %%
print("Latest Update on the total vaccines already delivered\n")
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region']=='World']
# Out:
# Latest Update on the total vaccines already delivered
#     Province_State Country_Region        Date   Doses_admin  \
# 630            NaN          World  2021-12-01  8.026806e+09
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 630                 4.231835e+09             3.344885e+09         2021-12-01
#
#      UID
# 630  NaN

# %%
# total_confirmed_vaccine_global.drop(total_confirmed_vaccine_global.tail(1).index,inplace=True)
total_confirmed_vaccine_global
# Out:
#     Province_State      Country_Region        Date   Doses_admin  \
# 0              NaN         Afghanistan  2021-12-01  5.116767e+06
# 1              NaN             Albania  2021-12-01  2.096897e+06
# 2              NaN             Algeria  2021-12-01  1.207687e+07
# 3              NaN             Andorra  2021-12-01  1.045340e+05
# 4              NaN              Angola  2021-12-01  9.026310e+06
# ..             ...                 ...         ...           ...
# 629            NaN  West Bank and Gaza  2021-12-01  3.024477e+06
# 630            NaN               World  2021-12-01  8.026806e+09
# 631            NaN               Yemen  2021-12-01  7.749530e+05
# 632            NaN              Zambia  2021-12-01  1.086607e+06
# 633            NaN            Zimbabwe  2021-12-01  6.611942e+06
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 0                   4.285440e+06             3.454113e+06         2021-12-01
# 1                   1.071871e+06             9.595550e+05         2021-12-01
# 2                   6.716299e+06             5.340231e+06         2021-12-01
# 3                   5.499900e+04             4.953500e+04         2021-12-01
# 4                   6.266044e+06             2.760266e+06         2021-12-01
# ..                           ...                      ...                ...
# 629                          NaN                      NaN         2021-12-01
# 630                 4.231835e+09             3.344885e+09         2021-12-01
# 631                 5.489330e+05             3.613510e+05         2021-12-01
# 632                 8.066110e+05             6.917350e+05         2021-12-01
# 633                 3.795401e+06             2.816541e+06         2021-12-01
#
#        UID
# 0      4.0
# 1      8.0
# 2     12.0
# 3     20.0
# 4     24.0
# ..     ...
# 629  275.0
# 630    NaN
# 631  887.0
# 632  894.0
# 633  716.0
#
# [634 rows x 8 columns]

# %%
country = ['Luxembourg', 'Vietnam', 'Germany', 'UK', 'US', 'Denmark']
total_confirmed_vaccine_global[total_confirmed_vaccine_global['Country_Region'].isin(country)]
# Out:
#              Province_State Country_Region        Date  Doses_admin  \
# 153                     NaN        Denmark  2021-12-01    9791522.0
# 154           Faroe Islands        Denmark  2021-12-01      78347.0
# 155               Greenland        Denmark  2021-12-01      77655.0
# 210                     NaN        Germany  2021-12-01  123348281.0
# 211       Baden-Wurttemberg        Germany  2021-12-01   15892150.0
# 212                  Bayern        Germany  2021-12-01   19135028.0
# 213                  Berlin        Germany  2021-12-01    5631636.0
# 214             Brandenburg        Germany  2021-12-01    3368383.0
# 215                  Bremen        Germany  2021-12-01    1159041.0
# 216                 Hamburg        Germany  2021-12-01    2905977.0
# 217                  Hessen        Germany  2021-12-01    9180433.0
# 218  Mecklenburg-Vorpommern        Germany  2021-12-01    2321863.0
# 219           Niedersachsen        Germany  2021-12-01   12063719.0
# 220     Nordrhein-Westfalen        Germany  2021-12-01   28005867.0
# 221         Rheinland-Pfalz        Germany  2021-12-01    6107795.0
# 222                Saarland        Germany  2021-12-01    1596235.0
# 223                 Sachsen        Germany  2021-12-01    5125204.0
# 224          Sachsen-Anhalt        Germany  2021-12-01    3025698.0
# 225      Schleswig-Holstein        Germany  2021-12-01    4548481.0
# 226               Thuringen        Germany  2021-12-01    2890352.0
# 227                 Unknown        Germany  2021-12-01          0.0
# 394                     NaN     Luxembourg  2021-12-01     917455.0
# 578                     NaN             US  2021-12-01  460773508.0
# 628                     NaN        Vietnam  2021-12-01  122083464.0
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 153                    4565137.0                4454053.0         2021-12-01
# 154                          NaN                      NaN         2021-12-01
# 155                          NaN                      NaN         2021-12-01
# 210                   59407188.0               57024545.0         2021-12-01
# 211                          NaN                      NaN         2021-12-01
# 212                          NaN                      NaN         2021-12-01
# 213                          NaN                      NaN         2021-12-01
# 214                          NaN                      NaN         2021-12-01
# 215                          NaN                      NaN         2021-12-01
# 216                          NaN                      NaN         2021-12-01
# 217                          NaN                      NaN         2021-12-01
# 218                          NaN                      NaN         2021-12-01
# 219                          NaN                      NaN         2021-12-01
# 220                          NaN                      NaN         2021-12-01
# 221                          NaN                      NaN         2021-12-01
# 222                          NaN                      NaN         2021-12-01
# 223                          NaN                      NaN         2021-12-01
# 224                          NaN                      NaN         2021-12-01
# 225                          NaN                      NaN         2021-12-01
# 226                          NaN                      NaN         2021-12-01
# 227                          NaN                      NaN         2021-12-01
# 394                     454957.0                 429705.0         2021-12-01
# 578                  233207582.0              197058988.0         2021-12-01
# 628                   71143392.0               50940072.0         2021-12-01
#
#          UID
# 153    208.0
# 154    234.0
# 155    304.0
# 210    276.0
# 211  27601.0
# 212  27602.0
# 213  27603.0
# 214  27604.0
# 215  27605.0
# 216  27606.0
# 217  27607.0
# 218  27608.0
# 219  27609.0
# 220  27610.0
# 221  27611.0
# 222  27612.0
# 223  27613.0
# 224  27614.0
# 225  27615.0
# 226  27616.0
# 227  27617.0
# 394    442.0
# 578    840.0
# 628    704.0

# %%
total_confirmed_vaccine_global.sort_values(by='Doses_admin', ascending=False).head(15).plot(x='Country_Region', y='Doses_admin', kind='bar')
plt.xticks(rotation=45)
total_confirmed_vaccine_global.sort_values(by='Doses_admin', ascending=False).head(15)
# Out:
#     Province_State  Country_Region        Date   Doses_admin  \
# 630            NaN           World  2021-12-01  8.026806e+09
# 91             NaN           China  2021-12-01  2.507975e+09
# 239            NaN           India  2021-12-01  1.249449e+09
# 578            NaN              US  2021-12-01  4.607735e+08
# 579            NaN  US (Aggregate)  2021-12-01  4.592945e+08
# 65             NaN          Brazil  2021-12-01  3.094866e+08
# 277            NaN       Indonesia  2021-12-01  2.373872e+08
# 340            NaN           Japan  2021-12-01  1.972662e+08
# 274  Uttar Pradesh           India  2021-12-01  1.637176e+08
# 421            NaN          Mexico  2021-12-01  1.326368e+08
# 481        Unknown          Russia  2021-12-01  1.279759e+08
# 480            NaN          Russia  2021-12-01  1.279759e+08
# 210            NaN         Germany  2021-12-01  1.233483e+08
# 452            NaN        Pakistan  2021-12-01  1.230321e+08
# 628            NaN         Vietnam  2021-12-01  1.220835e+08
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 630                 4.231835e+09             3.344885e+09         2021-12-01
# 91                  1.225000e+09             1.076308e+09         2021-12-01
# 239                 7.890542e+08             4.480009e+08         2021-12-01
# 578                 2.332076e+08             1.970590e+08         2021-12-01
# 579                 2.332076e+08             1.970590e+08         2021-12-01
# 65                  1.639265e+08             1.339112e+08         2021-12-01
# 277                 1.385302e+08             9.433974e+07         2021-12-01
# 340                 9.981294e+07             9.745322e+07         2021-12-01
# 274                          NaN                      NaN         2021-12-01
# 421                 7.684526e+07             6.503873e+07         2021-12-01
# 481                          NaN                      NaN         2021-12-01
# 480                 6.673862e+07             5.668119e+07         2021-12-01
# 210                 5.940719e+07             5.702454e+07         2021-12-01
# 452                 8.028486e+07             5.018410e+07         2021-12-01
# 628                 7.114339e+07             5.094007e+07         2021-12-01
#
#          UID
# 630      NaN
# 91     156.0
# 239    356.0
# 578    840.0
# 579    840.0
# 65      76.0
# 277    360.0
# 340    392.0
# 274  35633.0
# 421    484.0
# 481  64384.0
# 480    643.0
# 210    276.0
# 452    586.0
# 628    704.0

# %%
countries = ['China', 'Germany', 'Denmark', 'Korea, South', 'Japan', 'Australia', 'Luxembourg', 'US', 'United Kingdom', 'Canada', 'Vietnam', 'Philippines', 'Israel']

total_confirmed_vaccine_global.loc[total_confirmed_vaccine_global['Country_Region'].isin(countries)].groupby(by='Country_Region').sum().sort_values(by='Doses_admin', ascending=False)
# Out:
#                  Doses_admin  People_partially_vaccinated  \
# Country_Region
# China           2.518358e+09                 1.225000e+09
# US              4.607735e+08                 2.332076e+08
# Germany         2.463061e+08                 5.940719e+07
# United Kingdom  2.328736e+08                 5.096372e+07
# Japan           1.972662e+08                 9.981294e+07
# Vietnam         1.220835e+08                 7.114339e+07
# Canada          1.213905e+08                 3.048483e+07
# Philippines     8.642142e+07                 4.051797e+07
# Korea, South    8.534922e+07                 0.000000e+00
# Australia       7.858808e+07                 2.002520e+07
# Israel          1.619549e+07                 6.336252e+06
# Denmark         9.947524e+06                 4.565137e+06
# Luxembourg      9.174550e+05                 4.549570e+05
#
#                 People_fully_vaccinated       UID
# Country_Region
# China                      1.076308e+09     946.0
# US                         1.970590e+08     840.0
# Germany                    5.702454e+07  469629.0
# United Kingdom             4.636715e+07  343758.0
# Japan                      9.745322e+07     392.0
# Vietnam                    5.094007e+07     704.0
# Canada                     2.902281e+07  161418.0
# Philippines                3.636536e+07     608.0
# Korea, South               0.000000e+00     410.0
# Australia                  1.880881e+07   32481.0
# Israel                     5.776793e+06     376.0
# Denmark                    4.454053e+06     746.0
# Luxembourg                 4.297050e+05     442.0

# %%
total_confirmed_vaccine_global.loc[total_confirmed_vaccine_global['Country_Region'].isin(countries)]
# Out:
#                                    Province_State  Country_Region        Date  \
# 32                                            NaN       Australia  2021-12-01
# 33                   Australian Capital Territory       Australia  2021-12-01
# 34                                New South Wales       Australia  2021-12-01
# 35                             Northern Territory       Australia  2021-12-01
# 36                                     Queensland       Australia  2021-12-01
# ..                                            ...             ...         ...
# 620  Saint Helena, Ascension and Tristan da Cunha  United Kingdom  2021-12-01
# 621                                      Scotland  United Kingdom  2021-12-01
# 622                      Turks and Caicos Islands  United Kingdom  2021-12-01
# 623                                         Wales  United Kingdom  2021-12-01
# 628                                           NaN         Vietnam  2021-12-01
#
#      Doses_admin  People_partially_vaccinated  People_fully_vaccinated  \
# 32    39294041.0                   20025197.0               18808812.0
# 33      960008.0                          NaN                      NaN
# 34    12948843.0                          NaN                      NaN
# 35      382625.0                          NaN                      NaN
# 36     7223572.0                          NaN                      NaN
# ..           ...                          ...                      ...
# 620       7892.0                          NaN                      NaN
# 621    9984264.0                          NaN                      NaN
# 622      56343.0                          NaN                      NaN
# 623    5615851.0                          NaN                      NaN
# 628  122083464.0                   71143392.0               50940072.0
#
#     Report_Date_String      UID
# 32          2021-12-01     36.0
# 33          2021-12-01   3601.0
# 34          2021-12-01   3602.0
# 35          2021-12-01   3603.0
# 36          2021-12-01   3604.0
# ..                 ...      ...
# 620         2021-12-01    654.0
# 621         2021-12-01  82603.0
# 622         2021-12-01    796.0
# 623         2021-12-01  82604.0
# 628         2021-12-01    704.0
#
# [71 rows x 8 columns]

# %%
total_confirmed_vaccine_global.sort_values(by='People_partially_vaccinated', ascending=False).head(15).plot(x='Country_Region', y='People_partially_vaccinated', kind='bar')
plt.xticks(rotation=45)
total_confirmed_vaccine_global.sort_values(by='People_partially_vaccinated', ascending=False).head(15)
# Out:
#     Province_State  Country_Region        Date   Doses_admin  \
# 630            NaN           World  2021-12-01  8.026806e+09
# 91             NaN           China  2021-12-01  2.507975e+09
# 239            NaN           India  2021-12-01  1.249449e+09
# 578            NaN              US  2021-12-01  4.607735e+08
# 579            NaN  US (Aggregate)  2021-12-01  4.592945e+08
# 65             NaN          Brazil  2021-12-01  3.094866e+08
# 277            NaN       Indonesia  2021-12-01  2.373872e+08
# 340            NaN           Japan  2021-12-01  1.972662e+08
# 452            NaN        Pakistan  2021-12-01  1.230321e+08
# 421            NaN          Mexico  2021-12-01  1.326368e+08
# 628            NaN         Vietnam  2021-12-01  1.220835e+08
# 480            NaN          Russia  2021-12-01  1.279759e+08
# 46             NaN      Bangladesh  2021-12-01  9.643484e+07
# 210            NaN         Germany  2021-12-01  1.233483e+08
# 313            NaN            Iran  2021-12-01  1.046094e+08
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 630                 4.231835e+09             3.344885e+09         2021-12-01
# 91                  1.225000e+09             1.076308e+09         2021-12-01
# 239                 7.890542e+08             4.480009e+08         2021-12-01
# 578                 2.332076e+08             1.970590e+08         2021-12-01
# 579                 2.332076e+08             1.970590e+08         2021-12-01
# 65                  1.639265e+08             1.339112e+08         2021-12-01
# 277                 1.385302e+08             9.433974e+07         2021-12-01
# 340                 9.981294e+07             9.745322e+07         2021-12-01
# 452                 8.028486e+07             5.018410e+07         2021-12-01
# 421                 7.684526e+07             6.503873e+07         2021-12-01
# 628                 7.114339e+07             5.094007e+07         2021-12-01
# 480                 6.673862e+07             5.668119e+07         2021-12-01
# 46                  5.983972e+07             3.659513e+07         2021-12-01
# 210                 5.940719e+07             5.702454e+07         2021-12-01
# 313                 5.733285e+07             4.632834e+07         2021-12-01
#
#        UID
# 630    NaN
# 91   156.0
# 239  356.0
# 578  840.0
# 579  840.0
# 65    76.0
# 277  360.0
# 340  392.0
# 452  586.0
# 421  484.0
# 628  704.0
# 480  643.0
# 46    50.0
# 210  276.0
# 313  364.0

# %%
total_confirmed_vaccine_global.sort_values(by='People_fully_vaccinated', ascending=False).head(15).plot(x='Country_Region', y='People_fully_vaccinated', kind='bar')
plt.xticks(rotation=45)
total_confirmed_vaccine_global.sort_values(by='People_fully_vaccinated', ascending=False).head(15)
# Out:
#     Province_State  Country_Region        Date   Doses_admin  \
# 630            NaN           World  2021-12-01  8.026806e+09
# 91             NaN           China  2021-12-01  2.507975e+09
# 239            NaN           India  2021-12-01  1.249449e+09
# 579            NaN  US (Aggregate)  2021-12-01  4.592945e+08
# 578            NaN              US  2021-12-01  4.607735e+08
# 65             NaN          Brazil  2021-12-01  3.094866e+08
# 340            NaN           Japan  2021-12-01  1.972662e+08
# 277            NaN       Indonesia  2021-12-01  2.373872e+08
# 421            NaN          Mexico  2021-12-01  1.326368e+08
# 210            NaN         Germany  2021-12-01  1.233483e+08
# 480            NaN          Russia  2021-12-01  1.279759e+08
# 628            NaN         Vietnam  2021-12-01  1.220835e+08
# 577            NaN          Turkey  2021-12-01  1.203907e+08
# 452            NaN        Pakistan  2021-12-01  1.230321e+08
# 184            NaN          France  2021-12-01  1.052618e+08
#
#      People_partially_vaccinated  People_fully_vaccinated Report_Date_String  \
# 630                 4.231835e+09             3.344885e+09         2021-12-01
# 91                  1.225000e+09             1.076308e+09         2021-12-01
# 239                 7.890542e+08             4.480009e+08         2021-12-01
# 579                 2.332076e+08             1.970590e+08         2021-12-01
# 578                 2.332076e+08             1.970590e+08         2021-12-01
# 65                  1.639265e+08             1.339112e+08         2021-12-01
# 340                 9.981294e+07             9.745322e+07         2021-12-01
# 277                 1.385302e+08             9.433974e+07         2021-12-01
# 421                 7.684526e+07             6.503873e+07         2021-12-01
# 210                 5.940719e+07             5.702454e+07         2021-12-01
# 480                 6.673862e+07             5.668119e+07         2021-12-01
# 628                 7.114339e+07             5.094007e+07         2021-12-01
# 577                 5.626169e+07             5.045836e+07         2021-12-01
# 452                 8.028486e+07             5.018410e+07         2021-12-01
# 184                 5.194081e+07             4.707844e+07         2021-12-01
#
#        UID
# 630    NaN
# 91   156.0
# 239  356.0
# 579  840.0
# 578  840.0
# 65    76.0
# 340  392.0
# 277  360.0
# 421  484.0
# 210  276.0
# 480  643.0
# 628  704.0
# 577  792.0
# 452  586.0
# 184  250.0

# %%
rcParams['figure.figsize'] = 20, 10
countries = {'Germany':"blue", 'Vietnam':"orange", 'Luxembourg':"lightblue", 'Japan':"red", 'Denmark':"green"}

plt.figure()
for country in countries.keys():
    
    time_series_vaccine_global[time_series_vaccine_global['Country_Region']==country].groupby(by='Date').sum()['Doses_admin'].plot(color=countries[country], label=country)
    # time_series_vaccine_global[time_series_vaccine_global['Country_Region']==country][['Date', 'Doses_admin']].plot.scatter(x='Date', y='Doses_admin', color=countries[country], label=country)
    # time_series_vaccine_global[time_series_vaccine_global['Country_Region']=='Vietnam'][['Date', 'Doses_admin']].plot.scatter(ax=ax, x='Date', y='Doses_admin', color=, label='Vietnam')
    # time_series_vaccine_global[time_series_vaccine_global['Country_Region']=='Luxembourg'][['Date', 'Doses_admin']].plot.scatter(ax=ax, x='Date', y='Doses_admin', color=, label='Luxembourg')
    # time_series_vaccine_global[time_series_vaccine_global['Country_Region']=='Japan'][['Date', 'Doses_admin']].plot.scatter(ax=ax, x='Date', y='Doses_admin', color=, label='Japan')
    # time_series_vaccine_global[time_series_vaccine_global['Country_Region']=='Denmark'][['Date', 'Doses_admin']].plot.scatter(ax=ax, x='Date', y='Doses_admin', color=, label='Denmark')

    plt.xticks(np.arange(0, time_series_vaccine_global[time_series_vaccine_global['Country_Region']==country].shape[0], 10), rotation=45)
    plt.title("Vaccination speed")
    plt.legend()

for country in countries.keys():
    print(country, time_series_vaccine_global[time_series_vaccine_global['Country_Region']==country].groupby(by='Date').sum().tail(1)['Doses_admin'].values[0])
# Out:
# Germany 246306143.0
# Vietnam 120644108.0
# Luxembourg 917455.0
# Japan 197101669.0
# Denmark 9912811.0

# %%
time_series_vaccine_global[time_series_vaccine_global['Country_Region']=="Germany"].loc[103031]
# Out:
# Country_Region                    Germany
# Date                           2021-11-07
# Doses_admin                           0.0
# People_partially_vaccinated           NaN
# People_fully_vaccinated               NaN
# Report_Date_String             2021-11-08
# UID                               27617.0
# Province_State                    Unknown
# Name: 103031, dtype: object

# %%
time_series_vaccine_global[time_series_vaccine_global['Country_Region']=="Germany"].iloc

# %%
countries.keys()
# Out:
# dict_keys(['Germany', 'Vietnam', 'Luxembourg', 'Japan', 'Denmark'])
